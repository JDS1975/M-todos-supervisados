# %% [markdown]
# <a href="https://colab.research.google.com/github/JDS1975/M-todos-supervisados/blob/main/20222_M2_855_PEC3_JORGE_DIAZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.855 · Modelos avanzados de minería de datos</p>
# <p style="margin: 0; text-align:right;">2022-2 · Máster universitario en Ciencia de datos (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# # PEC 3: Métodos supervisados
#
# En esta práctica veremos diferentes métodos supervisados y trataremos de optimizar diferentes métricas. Veremos como los diferentes modelos clasifican los puntos y con cuales obtenemos mayor precisión. Después aplicaremos todo lo que hemos aprendido hasta ahora a un dataset nuevo simulando un caso práctico real.
#
# 1. [Exploración de algoritmos supervisados](#eje1) \
#     1.0. Carga de datos \
#     1.1. Naive-Bayes\
#     1.2. Análisis Discriminante Lineal (LDA) y Análisis Discriminante Cuadrtático (QDA)\
#     1.3. K vecinos más próximos (KNN)\
#     1.4. Máquinas de soporte vectorial (SVM)\
#     1.5. Árboles de decisión
# 2. [Implementación del caso práctico](#ej2)\
#     2.0. Carga de datos\
#     2.1. Análisis descriptivo\
#     2.2. Entrenamiento, validación y prueba de una red neuronal con los datos originales\
#     2.3. Submuestreo\
#     2.4. Sobremuestreo\
#     2.5. Generación de datos sintéticos\
#     2.6. Sintonizando los modelos (BONUS)
#
# <u>Consideraciones generales</u>:
#
# - La solución planteada no puede utilizar métodos, funciones o parámetros declarados **_deprecated_** en futuras versiones, a excepción de la carga de datos cómo se indica posteriormente.
# - Esta PEC debe realizarse de forma **estrictamente individual**. Cualquier indicio de copia será penalizado con un suspenso (D) para todas las partes implicadas y la posible evaluación negativa de la asignatura de forma íntegra.
# - Es necesario que el estudiante indique **todas las fuentes** que ha utilizado para la realización de la PEC. De no ser así, se considerará que el estudiante ha cometido plagio, siendo penalizado con un suspenso (D) y la posible evaluación negativa de la asignatura de forma íntegra.
#
# <u>Formato de la entrega</u>:
#
# - Algunos ejercicios pueden suponer varios minutos de ejecución, por lo que la entrega debe hacerse en **formato notebook** y en **formato html**, donde se vea el código, los resultados y comentarios de cada ejercicio. Se puede exportar el notebook a HTML desde el menú File $\to$ Download as $\to$ HTML.
# - Existe un tipo de celda especial para albergar texto. Este tipo de celda os será muy útil para responder a las diferentes preguntas teóricas planteadas a lo largo de la actividad. Para cambiar el tipo de celda a este tipo, en el menú: Cell $\to$ Cell Type $\to$ Markdown.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Nombre y apellidos:</strong>
# </div>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns

from sklearn import datasets, tree
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from sklearn.model_selection import train_test_split, GridSearchCV,RepeatedStratifiedKFold
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.utils import check_random_state
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.model_selection import KFold

# Visualizar árboles
from IPython.display import Image
import pydotplus
from six import StringIO

# Visualización.
import matplotlib as mpl
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# <a id='ej1'></a>
# # 1. Exploración de algoritmos supervisados
#
# ## 1.0. Carga de datos
#
# El conjunto de datos Spiral es un conjunto de datos sintéticos que se utiliza comúnmente en el aprendizaje automático y la minería de datos como un problema de clasificación no lineal. El conjunto de datos consta de dos espirales entrelazadas que se asemejan a las espirales de Arquímedes. Cada espiral se compone de un conjunto de puntos distribuidos uniformemente en el plano, y los puntos de cada espiral están etiquetados con una clase diferente.
#
# El objetivo es utilizar un algoritmo de clasificación para predecir la clase de un punto desconocido en función de sus coordenadas (x, y). Debido a la naturaleza entrelazada de las espirales, este problema de clasificación es no lineal y, por lo tanto, es un desafío interesante para los algoritmos de aprendizaje automático.
#
# El siguiente código cargará 2000 puntos en la variable `X` y la correspondientes etiqueta o grupo (en forma numérica) en la variable `y`. Podemos comprobar que la carga ha sido correcta obteniendo las dimensiones de estas dos variables y el gráfico de los puntos (con colores diferentes para cada grupo).

# %%
data = pd.read_pickle('spiral.pickle')

# Convertir las dos primeras columnas en un array de numpy
X = data[['X1', 'X2']].values

# Convertir la última columna en un array de numpy
y = data['y'].values

print('Dimensiones de X', X.shape)
print('Dimensiones de y', y.shape)

# Hacer la representación gráfica
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.viridis, alpha=0.5)
plt.show()
# Out:
# Dimensiones de X (2000, 2)
# Dimensiones de y (2000,)

# %%
data.head()
# Out:
#          X1        X2    y
# 0 -0.723086  1.398472  0.0
# 1  1.638987 -0.543341  2.0
# 2  0.438198  0.363253  2.0
# 3 -0.461198  0.487286  1.0
# 4 -1.542407 -1.875442  3.0

# %%
data.groupby(['y']).size()
# Out:
# y
# 0.0    500
# 1.0    500
# 2.0    500
# 3.0    500
# dtype: int64

# %% [markdown]
# De cada categoría tenemos 500 observaciones. Como podemos ver tenemos 4 categorias en la varoable "y"

# %% [markdown]
# A lo largo de los ejercicios aprenderemos a ver gráficamente las fronteras de decisión que nos devuelven los diferentes modelos. Para ello utilizaremos la función definida a continuación, que sigue los siguientes pasos:
#
#    - Crear una [meshgrid](https://docs.scipy.org/doc/numpy/reference/generated/numpy.meshgrid.html) con los valores mínimo y máximo de 'x' e 'y'.
#    - Predecir el clasificador con los valores de la _meshgrid_.
#    - Hacer un _reshape_ de los datos para tener el formato correspondiente.
#
# Una vez hecho esto, ya podemos hacer el gráfico de las fronteras de decisión y añadir los puntos reales. Así veremos las áreas que el modelo considera que son de una clase y las que considera que son de otra. Al poner encima los puntos veremos si los clasifica correctamente en el área que les corresponde.

# %%
def plot_decision_boundary(clf, X, Y, cmap='Paired'):
    if not isinstance(X, np.ndarray):  # Si X no es un array de numpy, lo convierte
        X = X.to_numpy()
    
    h = 0.02
    x_min, x_max = X[:,0].min() - 10*h, X[:,0].max() + 10*h
    y_min, y_max = X[:,1].min() - 10*h, X[:,1].max() + 10*h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(7,7))
    plt.contourf(xx, yy, Z, cmap=cmap, alpha=0.25)
    plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
    plt.scatter(X[:,0], X[:,1], c=Y, cmap=cmap, edgecolors='k', label=Y);

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Implementación:</strong>
#
# Dividid el _dataset_ en dos subconjuntos, __*train*__ (80% de los datos) y __*test*__ (20% de los datos). Nombrad los conjuntos como: X_train, X_test, y_train, y_test. Utilizad la opción `random_state = 24`.
#
# Podéis utilizar la implementación `train_test_split` de `sklearn`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, random_state=24,stratify=y)

# %% [markdown]
# Stratify: para que la proporción de valores en la muestra producida sea la misma que la proporción de valores proporcionados al parámetro stratify. Tal y como hemos visto anteriormente la variable categórica tiene la misma cantidad de datos por cada categoría (500). Al usar el parametro stratify conseguimos que la distribución sea igual. Por lo que vemos mas abajo se la misma distribución.

# %% [markdown]
# ### 1.1. Gaussian Naïve Bayes
#
# El objetivo de este primer ejercicio es entender el funcionamiento del algoritmo Naïve-Bayes, un algoritmo peculiar ya que se basa en el teorema de Bayes para calcular la probabilidad de que una observación pertenezca a cada una de las clases. El modelo asume que las características de entrada son independientes entre sí, lo que permite simplificar el cálculo de las probabilidades condicionales.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un modelo de Naïve-Bayes. Podéis utilizar el clasificador `GaussianNB` de `sklearn`.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
# Podéis utilizar la función `plot_decision_boundary` creada previamente, y las funciones `accuracy_score` y `confusion_matrix` del paquet `metrics` de `sklearn`.
# </div>

# %% [markdown]
# Entrenamiento del modelo.

# %%
clf = GaussianNB()
clf.fit(X_train,y_train)  
y_pred = clf.predict(X_test)

# %% [markdown]
# Exactitud del modelo

# %%
print("Exactitud:",accuracy_score(y_test, y_pred))
# Out:
# Exactitud: 0.2675

# %%
def matriz_confusion(model_fit, X_test, y_test, labels=['0', '1', '2', '3']):
    # Predicciones
    y_pred = model_fit.predict(X_test)
    
    # Matriz de confusuón
    mat = confusion_matrix(y_test, y_pred)

    # Representación gráfica matriz de confusuón
    ax = sns.heatmap(mat, square=True, annot=True, cbar=False, cmap='GnBu', fmt='d', linewidths=4)
    ax.invert_yaxis()
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    plt.xlabel('Predicted Label');
    plt.ylabel('True Label')

# %%
matriz_confusion(clf.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(clf,X_test,y_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Las fronteras de decisión tienen un forma irregular y se aprecian regiones para un mismo grupo de datos con separación entre las mismas. Tiene sentido que el algoritmo haya dado como resultado ese tipo de fronteras por dos razones:
#
#
# 1.   Se trata de un algoritmo que se basa en probabilidades.
# 2.   El conjunto de datos son cuatro categorías de datos en espiral con valores numéricos.
#
# Las predicciones son malas y solo se obtiene un 0.2675 de exactitud.
#
#
#
# </div>

# %% [markdown]
# ### 1.2 Análisis Discriminante Lineal (LDA) y Análisis Discriminante Cuadrtático (QDA)
#
# Ahora analizaremos dos algoritmos que se basan en la transformación lineal de las características de entrada para maximizar la separación entre las clases. Estos modelos suponen que las características tienen una distribución gaussiana y así poder calcular las probabilidades condicionales de cada clase y asignar la clase con la mayor probabilidad como la clase predicha para una observación dada.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un modelo de Análisis Discriminate Lineal (LDA). Podéis utilizar el clasificador `LinearDiscriminantAnalysis` de `sklearn`.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
# </div>

# %%
model = LinearDiscriminantAnalysis()
model.fit_transform(X_train,y_train)
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.225

# %%
matriz_confusion(model.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(model,X_test,y_test)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Las fronteras de decision presentan cuatro regiones con forma triangular. El algorritmo trata de encontrar una combinación lineal de caractaristicas que separan a los grupos. Debido a que el conjunto de datos es en espiral, este algoritmo nos clasifica bien ya que las coordenadas de muchos de los datos son muy similares y es muy dificil obtener una combinación lineal de los grupos.
# Las prediciones son malas obteniendo solo 0.225 de exactitud.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un modelo de Análisis Discriminate Cuadrático (QDA). Podéis utilizar el clasificador `QuadraticDiscriminantAnalysis` de `sklearn`.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
# </div>

# %%
model = QuadraticDiscriminantAnalysis() # modelo
model.fit(X_train, y_train) # entrenamiento del modelo
# Out:
# QuadraticDiscriminantAnalysis()

# %%
y_pred = model.predict(X_test) # array con las perdicciones

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
accuracy_score(y_test, y_pred) # exactitud
# Out:
# 0.2475

# %%
matriz_confusion(model.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(model,X_test,y_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
#    - ¿En que se diferencian el algoritmo LDA del QDA?
# </div>

# %% [markdown]
# [texto del enlace](https://)<div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Las fronteras de decision presentan formas irregulares y nuevamente se obtienen regiones separadas para un mismo grupo de datos o categoria. Al usar una función cuadratica en vez de una función lineal para separar los grupos las fronteras de decision no tienen una forma lienal como en el algoritmo anterior.
#
# Las predicciones no son buenas y solo se obtiene una exactitud de 0.2475.
#
# La principal diferencia entre el LDA y el QDA es que el LDA asume que las matrices de covarianza de los grupos son iguales, mientras que el QDA no lo hace. En el QDA, la distancia al cuadrado no se simplifica en una función lineal, lo que lo hace diferente del LDA. En lugar de eso, se utiliza una función cuadrática para calcular la distancia al cuadrado.
#
#
#
# </div>

# %% [markdown]
# ### 1.3. K- vecinos más próximos KNN
#
# En este punto entenderemos el funcionamiento del algoritmo KNN (que se basa en la proximidad de los puntos de datos en un espacio de características), intuir sus principales ventajas o desventajas y entender la influencia de los parámetros de los que está compuesto.
#
# K-Nearest-Neighbor es un algoritmo basado en instancia de tipo supervisado.
#
# Vamos a ver qué significa esto:
#
#   - Supervisado: tenemos etiquetado nuestro conjunto de datos de entrenamiento, con la clase o resultado esperado.
#   - Basado en instancia (_Lazy Learning_): Esto significa que nuestro algoritmo no aprende explícitamente un modelo (como por ejemplo en Regresión Logística o árboles de decisión), sino que memoriza las instancias de entrenamiento que son utilizadas como "conocimiento" para la fase de predicción.
#
# ¿Cómo funciona KNN?
#
#   - Calculamos la distancia entre el ítem a clasificar y los demás ítems del dataset de entrenamiento.
#   - Seleccionamos los "k" elementos más cercanos, es decir, con menor distancia, según la distancia que utilizamos (euclídea, coseno, manhattan, etc).
#   - Por último realizamos una "votación de mayoría" entre los k puntos: los de la clase que "dominan" decidirán su clasificación final.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un clasificador KNN con hiperparámetro `n_neighbors=2`. Podéis utilizar el clasificador `KNeighborsClassifier` de `sklearn`.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
#
# Si al entrenar el clasificador sale un warning y lo quieres ignorar, ejecuta el siguiente código antes del entrenamiento:
#
# `import warnings`\
# `warnings.filterwarnings('ignore', message='^.*will change.*$', category=FutureWarning)`
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore', message='^.*will change.*$', category=FutureWarning)

# %%
knn = KNeighborsClassifier(n_neighbors=2) # modelo
knn.fit(X_train,y_train) # entrenamiento del modelo
y_pred = knn.predict(X_test) # array con predicciones
accuracy_score(y_test, y_pred) # exactitud
# Out:
# 0.785

# %%
matriz_confusion(knn.fit(X_train,y_train), X_test, y_test) # matriz de confusión

# %%
plot_decision_boundary(knn,X_test,y_test)

# %% [markdown]
# En el modelo entrenado, hemos fijado el parámetro `n_neighbors` de forma arbitraria. Pero podría ser que con otro valor obtuviéramos una mejor predicción.
#
# Para conocer el valor óptimo de los parámetros de un modelo (_hyperparameter tunning_) se suele utilizar una búsqueda de rejilla (_grid search_). Es decir, entrenar un modelo para cada combinación de hiperparámetros posible y evaluarlo utilizando validación cruzada (_cross validation_) con 5 particiones estratificadas. Posteriormente, se elige la combinación de hiperparàmetres que mejores resultados haya obtenido.
#
# En este caso sólo queremos optimizar un hiperparámetro:
#
#    - 𝑘: el número de vecinos que se consideran para clasificar un nuevo ejemplo. Probaremos con todos los valores entre 1 y 20.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Implementación:</strong>
#
# Cálculo del valor óptimo del hiperparámetro _k_ (`n_neighbors`). Utilizad una búsqueda de rejilla con validación cruzada para encontrar el valor óptimo de _k_. Por cada valor, calculad su promedio y la desviación estándar. Implementad un _heatmap_ para visualizar la precisión según los diferentes valores del hiperparámetro.
#
# Puede utilizar el módulo `GridSearchCV` de `sklearn` el cálculo del mejor hiperparámetro, y `heatmap` de `Seaborn`.
# </div>

# %%
param_grid = {"n_neighbors": range(1, 21)} # valores K
grid = GridSearchCV(knn, param_grid) # Búsqueda de valores de parámetros específicos de un estimador. Por defecto 5 particiones estratificadas.
grid_search=grid.fit(X_train, y_train) # Búsqueda mejores valores en nuestros datos.
print(grid_search.best_params_) # Mejor valor de k encontrado.
# Out:
# {'n_neighbors': 6}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
# Cálculo de promedio y desviación estándar para cada valor de K
for i in range(0,20):
    print("k = {}:  Precisión media = {} | Desviación Estándar = {}".format(i + 1,
            round(grid.cv_results_['mean_test_score'][i], 4),
            round(grid.cv_results_["std_test_score"][i], 4)))
# Out:
# k = 1:  Precisión media = 0.7506 | Desviación Estándar = 0.0199
# k = 2:  Precisión media = 0.7587 | Desviación Estándar = 0.0103
# k = 3:  Precisión media = 0.7712 | Desviación Estándar = 0.0169
# k = 4:  Precisión media = 0.7719 | Desviación Estándar = 0.0077
# k = 5:  Precisión media = 0.7775 | Desviación Estándar = 0.0118
# k = 6:  Precisión media = 0.79 | Desviación Estándar = 0.0122
# k = 7:  Precisión media = 0.7813 | Desviación Estándar = 0.0131
# k = 8:  Precisión media = 0.7812 | Desviación Estándar = 0.018
# k = 9:  Precisión media = 0.7819 | Desviación Estándar = 0.0146
# k = 10:  Precisión media = 0.7781 | Desviación Estándar = 0.0171
# k = 11:  Precisión media = 0.7731 | Desviación Estándar = 0.012
# k = 12:  Precisión media = 0.7769 | Desviación Estándar = 0.0162
# k = 13:  Precisión media = 0.78 | Desviación Estándar = 0.0138
# k = 14:  Precisión media = 0.7781 | Desviación Estándar = 0.0144
# k = 15:  Precisión media = 0.7838 | Desviación Estándar = 0.0219
# k = 16:  Precisión media = 0.7838 | Desviación Estándar = 0.0182
# k = 17:  Precisión media = 0.7744 | Desviación Estándar = 0.0137
# k = 18:  Precisión media = 0.775 | Desviación Estándar = 0.0161
# k = 19:  Precisión media = 0.7775 | Desviación Estándar = 0.0174
# k = 20:  Precisión media = 0.7712 | Desviación Estándar = 0.013

# %%
# Heatmap de la precisión
ax = sns.heatmap(pd.DataFrame(grid.cv_results_['mean_test_score'], columns=["Precisión media"]), square=False, annot=True, cbar=False, cmap='GnBu', linewidths=4)
ax.invert_yaxis()
ax.set_yticklabels(range(1, 21))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un clasificador KNN con el mejor hiperparámetro encontrado.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
# </div>

# %%
knn = KNeighborsClassifier(n_neighbors=grid_search.best_params_['n_neighbors']) # modelo con k = 6
knn.fit(X_train, y_train) # entrenamiento del modelo
y_pred = knn.predict(X_test) # predicción
print("Exactitud:",accuracy_score(y_test, y_pred)) # exactitud
# Out:
# Exactitud: 0.82

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
matriz_confusion(knn.fit(X_train,y_train), X_test, y_test) # matriz de confusión

# %%
plot_decision_boundary(knn.fit(X_train, y_train), X_test, y_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - Comentar los resultados de la búsqueda del mejor hiperparámetro.
#    - ¿Cómo se visualiza gráficamente el cambio del valor `n_neighbors`? ¿Tiene sentido esta diferencia entre los dos gráficos al cambiar el parámetro?
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# La busqueda del mejor hiperparametro se realiza mediante validación cruzada. La validación cruzada permite probar el rendimiento del modelo predictivo con nuevos datos. El mejor hiperparámetro es para k=6
#
# A penas existe diferencia en la visualizacion grafica entre k=2 y k=6 ya que el algoritmo clasifica bien ya con k=2, dando una exactitud de 0.785 y con k=6 de 0.82.
#
# Las fronteras de decisión presentan una forma de espiral con cuatro regiones claremnte diferenciadas.
#
# Si tiene sentido que con este algoritmo se obtengas esas fronteras en forma de espiral ya que knn utiliza la proximidad para hacer clasificaciones o predicciones sobre la agrupación de un punto de datos individual.
#
# Las prediccicones son buenas, siendo mejor para k=6 donde se obtiene una exactitud de 0.82 frente a 0.785 para k=2
#
# </div>

# %% [markdown]
# ### 1.4. Máquinas de soporte vectorial SVM
#
# Las Support Vector Machine (SVM) se fundamentan en el _Maximal Margin Classifier_, que a su vez, se basan en el concepto de hiperplano.
#
# En un espacio p-dimensional, un hiperplano se define como un subespacio plano y afín de dimensiones p-1. El término afín significa que el subespacio no debe pasar por el origen. En un espacio de dos dimensiones, el hiperplano es un subespacio de 1 dimensión, es decir, una recta. En un espacio tridimensional, un hiperplano es un subespacio de dos dimensiones, un plano convencional. Para dimensiones p>3 no es intuitivo visualizar un hiperplano, pero el concepto de subespacio con p-1 dimensiones se mantiene.
#
# La definición de hiperplano para casos perfectamente separables linealmente resulta en un número infinito de posibles hiperplanos, lo que hace necesario un método que permita seleccionar uno de ellos como clasificador óptimo.
#
# La solución a este problema consiste en seleccionar como clasificador óptimo al que se conoce como _maximal margin hyperplane_ o hiperplano óptimo de separación, que se corresponde con el hiperplano que se encuentra más alejado de todas las observaciones de entrenamiento. Para obtenerlo, se debe calcular la distancia perpendicular de cada observación a un determinado hiperplano. La menor de estas distancias (conocida como margen) determina cómo de lejos está el hiperplano de las observaciones de entrenamiento. El _maximal margin hyperplane_ se define como el hiperplano que consigue un mayor margen, es decir, que la distancia mínima entre el hiperplano y las observaciones es lo más grande posible. Aunque esta idea suena razonable, no es posible aplicarla, ya que habría infinitos hiperplanos contra los que medir las distancias. En su lugar, se recurre a métodos de optimización.
#
# El proceso de optimización tiene la peculiaridad de que sólo las observaciones que se encuentran justo al margen o que lo violan influyen sobre el hiperplano. A estas observaciones se les conoce como vectores soporte (_vectors suport_) y son las que definen el clasificador obtenido.

# %% [markdown]
# #### Los _kernels_ en SVM
#
# Hay veces en que no hay manera de encontrar un hiperplano que permita separar dos clases. En estos casos decimos que las clases no son linealmente separables. Para resolver este problema podemos utilizar el truco del núcleo .
#
# El truco del núcleo (_kernel trick_) consiste en utilizar una dimensión nueva en la que podamos encontrar un hiperplano para separar las clases. Se puede ver un un ejemplo en: https://www.youtube.com/watch?v=OdlNM96sHio
#
# Al igual que en el algoritmo visto anteriormente (KNN), las SVM también dependen de varios hiperparámetros.
#
# En este caso intentaremos optimizar dos hiperparámetros:
#
#   - **C**: es la regularización, es decir, el valor de penalización de los errores en la clasificación. Indica el compromiso entre obtener el hiperplano con el margen más grande posible y clasificar el máximo número de ejemplos correctamente. Probaremos los valores: 0.01, 0.1, 1, 10, 50, 100 y 200.
#
#   - **Gama**: coeficiente que multiplica la distancia entre dos puntos en el kernel radial. Para decirlo a "grosso modo", cuanto más pequeño es gama, más influencia tienen dos puntos cercanos. Probaremos los valores: 0.001, 0.01, 0.1, 1 y 10.
#
# Al igual que en el caso anterior, para validar el rendimiento del algoritmo con cada combinación de hiperparámetros utilizaremos validación cruzada (_cross-validation_) con 4 particiones estratificadas.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Implementación:</strong>
#
# Cálcular del valor óptimo de los hiperparámetros _C_ y _gama_. Utilizad una búsqueda de rejilla con validación cruzada para encontrar los valores óptimos. Para cada combinación de valores, calcular su promedio y la desviación estándar. Haced un _heatmap_ para visualizar la precisión según los diferentes valores de los hiperparámetros.
#
# Podéis utilizar el módulo `GridSearchCV` de `sklearn` el cálculo de los mejores hiperparámetros con el clasificador SVC (de `SVM` de `sklearn`), y `heatmap` de `Seaborn`.
# </div>

# %%
svm = SVC() # modelo
svm.fit(X_train, y_train) # entrenamiento del modelo 
val_C = [0.01, 0.1, 1, 10, 50, 100, 200] # coeficientes de regulación
val_gamma = [0.001, 0.01, 0.1, 1, 10] # coeficientes gamma
param_grid = {'C': val_C, 'gamma': val_gamma}

# ahora realizamos la selección de mejores parámetros con 4 paticiones estratificadas (cv=4) y obtenemos el mejor estimador elegido por la búsqueda
grid = GridSearchCV(svm, param_grid,cv = 4) 
grid_search = grid.fit(X_train, y_train) 
params = grid_search.cv_results_['params']
means = grid_search.cv_results_["mean_test_score"]
print(grid.best_params_)
# Out:
# {'C': 50, 'gamma': 1}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
for i in range(1, len(grid_search.cv_results_['params']) + 1):
    print("* Combinación de parámetros: {},\n \t**Precisión media: {}, Desviación Estándar: {}".format(
        grid_search.cv_results_['params'][i - 1],
        round(grid_search.cv_results_['mean_test_score'][i - 1], 4),
        round(grid_search.cv_results_['std_test_score'][i - 1], 4)))
# Out:
# * Combinación de parámetros: {'C': 0.01, 'gamma': 0.001},
#  	**Precisión media: 0.255, Desviación Estándar: 0.0061
# * Combinación de parámetros: {'C': 0.01, 'gamma': 0.01},
#  	**Precisión media: 0.2562, Desviación Estándar: 0.008
# * Combinación de parámetros: {'C': 0.01, 'gamma': 0.1},
#  	**Precisión media: 0.3037, Desviación Estándar: 0.0163
# * Combinación de parámetros: {'C': 0.01, 'gamma': 1},
#  	**Precisión media: 0.74, Desviación Estándar: 0.0219
# * Combinación de parámetros: {'C': 0.01, 'gamma': 10},
#  	**Precisión media: 0.7506, Desviación Estándar: 0.0062
# * Combinación de parámetros: {'C': 0.1, 'gamma': 0.001},
#  	**Precisión media: 0.255, Desviación Estándar: 0.0061
# * Combinación de parámetros: {'C': 0.1, 'gamma': 0.01},
#  	**Precisión media: 0.2538, Desviación Estándar: 0.0072
# * Combinación de parámetros: {'C': 0.1, 'gamma': 0.1},
#  	**Precisión media: 0.4906, Desviación Estándar: 0.0101
# * Combinación de parámetros: {'C': 0.1, 'gamma': 1},
#  	**Precisión media: 0.7881, Desviación Estándar: 0.0164
# * Combinación de parámetros: {'C': 0.1, 'gamma': 10},
#  	**Precisión media: 0.78, Desviación Estándar: 0.0169
# * Combinación de parámetros: {'C': 1, 'gamma': 0.001},
#  	**Precisión media: 0.2569, Desviación Estándar: 0.0037
# * Combinación de parámetros: {'C': 1, 'gamma': 0.01},
#  	**Precisión media: 0.28, Desviación Estándar: 0.0183
# * Combinación de parámetros: {'C': 1, 'gamma': 0.1},
#  	**Precisión media: 0.7356, Desviación Estándar: 0.0224
# * Combinación de parámetros: {'C': 1, 'gamma': 1},
#  	**Precisión media: 0.7912, Desviación Estándar: 0.0244
# * Combinación de parámetros: {'C': 1, 'gamma': 10},
#  	**Precisión media: 0.7762, Desviación Estándar: 0.008
# * Combinación de parámetros: {'C': 10, 'gamma': 0.001},
#  	**Precisión media: 0.2519, Desviación Estándar: 0.0045
# * Combinación de parámetros: {'C': 10, 'gamma': 0.01},
#  	**Precisión media: 0.5481, Desviación Estándar: 0.0323
# * Combinación de parámetros: {'C': 10, 'gamma': 0.1},
#  	**Precisión media: 0.7819, Desviación Estándar: 0.016
# * Combinación de parámetros: {'C': 10, 'gamma': 1},
#  	**Precisión media: 0.7887, Desviación Estándar: 0.0166
# * Combinación de parámetros: {'C': 10, 'gamma': 10},
#  	**Precisión media: 0.7744, Desviación Estándar: 0.0151
# * Combinación de parámetros: {'C': 50, 'gamma': 0.001},
#  	**Precisión media: 0.2662, Desviación Estándar: 0.0118
# * Combinación de parámetros: {'C': 50, 'gamma': 0.01},
#  	**Precisión media: 0.6144, Desviación Estándar: 0.0269
# * Combinación de parámetros: {'C': 50, 'gamma': 0.1},
#  	**Precisión media: 0.7919, Desviación Estándar: 0.0177
# * Combinación de parámetros: {'C': 50, 'gamma': 1},
#  	**Precisión media: 0.7931, Desviación Estándar: 0.0091
# * Combinación de parámetros: {'C': 50, 'gamma': 10},
#  	**Precisión media: 0.7525, Desviación Estándar: 0.0226
# * Combinación de parámetros: {'C': 100, 'gamma': 0.001},
#  	**Precisión media: 0.2844, Desviación Estándar: 0.0203
# * Combinación de parámetros: {'C': 100, 'gamma': 0.01},
#  	**Precisión media: 0.6494, Desviación Estándar: 0.0296
# * Combinación de parámetros: {'C': 100, 'gamma': 0.1},
#  	**Precisión media: 0.7881, Desviación Estándar: 0.0179
# * Combinación de parámetros: {'C': 100, 'gamma': 1},
#  	**Precisión media: 0.79, Desviación Estándar: 0.0064
# * Combinación de parámetros: {'C': 100, 'gamma': 10},
#  	**Precisión media: 0.7487, Desviación Estándar: 0.0262
# * Combinación de parámetros: {'C': 200, 'gamma': 0.001},
#  	**Precisión media: 0.325, Desviación Estándar: 0.0115
# * Combinación de parámetros: {'C': 200, 'gamma': 0.01},
#  	**Precisión media: 0.6712, Desviación Estándar: 0.0342
# * Combinación de parámetros: {'C': 200, 'gamma': 0.1},
#  	**Precisión media: 0.7931, Desviación Estándar: 0.0168
# * Combinación de parámetros: {'C': 200, 'gamma': 1},
#  	**Precisión media: 0.7856, Desviación Estándar: 0.011
# * Combinación de parámetros: {'C': 200, 'gamma': 10},
#  	**Precisión media: 0.74, Desviación Estándar: 0.0283

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
# Heatmap de la precisión
param1 = [x["C"] for x in params]
param2 = [x["gamma"] for x in params]

precisions = pd.DataFrame(zip(param1, param2, means), columns=['C', 'gamma', 'means'])
precisions = precisions.pivot('C', 'gamma', 'means')
sns.heatmap(precisions,cmap="Blues",annot = True).set(title="Means Heatmap")
# Out:
# [Text(0.5, 1.0, 'Means Heatmap')]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un modelo de SVM con la mejor combinación de parámetros encontrada.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
# </div>

# %%
# Modelo con hiperparámetros óptimos
svm = SVC(C=50, gamma=1) # modelo
svm.fit(X_train, y_train) # entrenamiento del modelo
print("Exactitud:",svm.score(X_test, y_test)) # exactitud
# Out:
# Exactitud: 0.8425

# %%
# Matriz de confusión
matriz_confusion(svm.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(svm.fit(X_train, y_train), X_test, y_test) # regiones

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - Comentar los resultados de la búsqueda de los mejores hiperparámetros.
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# La búsqueda de los mejores hiperparámetros que se realiza por validación cruzada, ofrece como mejores parametros la regularizacion para c=2 y gamma = 1.
# Las fronteras de decisión de una SVM dependen del kernel que se haya usado y de sus parámetros. En este caso se ha usado el kernel rbf (Radial Basis Function) que genera líneas curvadas. En este caso, el parametro gamma determina los radios de estas curvas: A valores altos de gamma le corresponden bajos radios de curvatura.
#
# Las predicciones han sido muy buenas, dando 0.8425 de precisión.
#
# </div>

# %% [markdown]
# ### 1.5. Árboles de decisión
#
# Los árboles de decisión son modelos predictivos formados por reglas binarias (si / no) con las que se consigue repartir las observaciones en función de sus atributos y predecir así el valor de la variable respuesta.
#
# Los árboles pueden ser **clasificadores** (para clasificar clases, tales como nuestro ejemplo), o bien **regresores** (para predecir variables continuas).

# %% [markdown]
# #### Construcción de un árbol
#
# La creación de las ramificaciones de los árboles se logra mediante el algoritmo de *recursive binary splitting*. Este algoritmo consta de tres pasos principales:
#
#    - El proceso se inicia en lo alto del árbol, donde todas las observaciones pertenecen a la misma región.
#    - Se identifican todos los posibles puntos de corte para cada uno de los predictores. Los puntos de corte son cada uno de sus niveles.
#    - se evalúan las posibles divisiones de cada predictor de acuerdo a una determinada medida. En el caso de los clasificadores se utilizan: *classification error rate*, Gini, entropía, chi-square.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un arbol de desición. Podéis utilizar el clasificador `DecisionTreeClassifier` (de `tree` de `sklearn`).
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
# - Representad el árbol. Podéis utilizar el comando `plot.tree` de la biblioteca `tree` de `sklearn`.
# </div>

# %%
clf = DecisionTreeClassifier(random_state=24)
clf.fit(X_train, y_train)
print("Accuracy on training set:", clf.score(X_train, y_train))
print("Accuracy on test set:", clf.score(X_test, y_test))
# Out:
# Accuracy on training set: 1.0
# Accuracy on test set: 0.75

# %%
# Matriz de confusión
matriz_confusion(clf.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(clf.fit(X_train, y_train), X_test, y_test)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.2995967735434478, 0.98, 'x[0] <= -0.905\ngini = 0.75\nsamples = 1600\nvalue = [400, 400, 400, 400]'),
#  Text(0.06929245283018869, 0.94, 'x[0] <= -1.872\ngini = 0.642\nsamples = 278\nvalue = [83, 2, 64, 129]'),
#  Text(0.02830188679245283, 0.9, 'x[1] <= 1.485\ngini = 0.506\nsamples = 120\nvalue = [3, 0, 47, 70]'),
#  Text(0.014339622641509434, 0.86, 'x[0] <= -2.789\ngini = 0.353\nsamples = 83\nvalue = [3, 0, 15, 65]'),
#  Text(0.0060377358490566035, 0.82, 'x[1] <= 0.229\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 12, 2]'),
#  Text(0.0030188679245283017, 0.78, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.009056603773584906, 0.78, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0]'),
#  Text(0.022641509433962263, 0.82, 'x[0] <= -2.466\ngini = 0.163\nsamples = 69\nvalue = [3, 0, 3, 63]'),
#  Text(0.01509433962264151, 0.78, 'x[0] <= -2.584\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 3, 11]'),
#  Text(0.009056603773584906, 0.74, 'x[0] <= -2.759\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10]'),
#  Text(0.0060377358490566035, 0.7, 'x[1] <= 0.271\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.0030188679245283017, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.009056603773584906, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.012075471698113207, 0.7, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
#  Text(0.021132075471698115, 0.74, 'x[1] <= 0.987\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.018113207547169812, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.024150943396226414, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.03018867924528302, 0.78, 'x[0] <= -1.935\ngini = 0.103\nsamples = 55\nvalue = [3, 0, 0, 52]'),
#  Text(0.027169811320754716, 0.74, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38]'),
#  Text(0.03320754716981132, 0.74, 'x[0] <= -1.933\ngini = 0.291\nsamples = 17\nvalue = [3, 0, 0, 14]'),
#  Text(0.03018867924528302, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.036226415094339624, 0.7, 'x[1] <= -0.421\ngini = 0.219\nsamples = 16\nvalue = [2, 0, 0, 14]'),
#  Text(0.03320754716981132, 0.66, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
#  Text(0.03924528301886793, 0.66, 'x[1] <= -0.329\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 0, 6]'),
#  Text(0.036226415094339624, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.04226415094339623, 0.62, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.04226415094339623, 0.86, 'x[0] <= -2.392\ngini = 0.234\nsamples = 37\nvalue = [0, 0, 32, 5]'),
#  Text(0.03924528301886793, 0.82, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0]'),
#  Text(0.045283018867924525, 0.82, 'x[1] <= 2.101\ngini = 0.401\nsamples = 18\nvalue = [0, 0, 13, 5]'),
#  Text(0.04226415094339623, 0.78, 'x[1] <= 1.869\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5]'),
#  Text(0.03924528301886793, 0.74, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.045283018867924525, 0.74, 'x[1] <= 1.936\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.04226415094339623, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.04830188679245283, 0.7, 'x[0] <= -2.207\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.045283018867924525, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.05132075471698113, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.04830188679245283, 0.78, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]'),
#  Text(0.11028301886792453, 0.9, 'x[1] <= 1.582\ngini = 0.592\nsamples = 158\nvalue = [80, 2, 17, 59]'),
#  Text(0.07566037735849057, 0.86, 'x[1] <= -1.873\ngini = 0.422\nsamples = 110\nvalue = [78, 2, 0, 30]'),
#  Text(0.057358490566037736, 0.82, 'x[1] <= -2.065\ngini = 0.172\nsamples = 21\nvalue = [2, 0, 0, 19]'),
#  Text(0.05433962264150943, 0.78, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16]'),
#  Text(0.06037735849056604, 0.78, 'x[0] <= -1.14\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.057358490566037736, 0.74, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.06339622641509433, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.0939622641509434, 0.82, 'x[0] <= -1.598\ngini = 0.255\nsamples = 89\nvalue = [76, 2, 0, 11]'),
#  Text(0.07547169811320754, 0.78, 'x[1] <= 0.852\ngini = 0.476\nsamples = 23\nvalue = [14, 0, 0, 9]'),
#  Text(0.06943396226415094, 0.74, 'x[1] <= -0.968\ngini = 0.375\nsamples = 16\nvalue = [12, 0, 0, 4]'),
#  Text(0.06641509433962264, 0.7, 'x[0] <= -1.743\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 0, 4]'),
#  Text(0.06339622641509433, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.06943396226415094, 0.66, 'x[0] <= -1.648\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2]'),
#  Text(0.06641509433962264, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.07245283018867925, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.07245283018867925, 0.7, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]'),
#  Text(0.08150943396226415, 0.74, 'x[0] <= -1.697\ngini = 0.408\nsamples = 7\nvalue = [2, 0, 0, 5]'),
#  Text(0.07849056603773585, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.08452830188679246, 0.7, 'x[0] <= -1.635\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.08150943396226415, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.08754716981132075, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.11245283018867924, 0.78, 'x[0] <= -0.929\ngini = 0.116\nsamples = 66\nvalue = [62, 2, 0, 2]'),
#  Text(0.10415094339622641, 0.74, 'x[1] <= -1.735\ngini = 0.09\nsamples = 64\nvalue = [61, 1, 0, 2]'),
#  Text(0.09660377358490566, 0.7, 'x[0] <= -1.259\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.09358490566037736, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.09962264150943397, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.11169811320754718, 0.7, 'x[1] <= 1.436\ngini = 0.064\nsamples = 61\nvalue = [59, 1, 0, 1]'),
#  Text(0.10566037735849057, 0.66, 'x[0] <= -1.076\ngini = 0.034\nsamples = 58\nvalue = [57, 1, 0, 0]'),
#  Text(0.10264150943396226, 0.62, 'gini = 0.0\nsamples = 49\nvalue = [49, 0, 0, 0]'),
#  Text(0.10867924528301887, 0.62, 'x[0] <= -1.072\ngini = 0.198\nsamples = 9\nvalue = [8, 1, 0, 0]'),
#  Text(0.10566037735849057, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.11169811320754718, 0.58, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]'),
#  Text(0.11773584905660377, 0.66, 'x[0] <= -1.239\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.11471698113207547, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.12075471698113208, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.12075471698113208, 0.74, 'x[1] <= -0.465\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.11773584905660377, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.12377358490566037, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.1449056603773585, 0.86, 'x[1] <= 2.639\ngini = 0.508\nsamples = 48\nvalue = [2, 0, 17, 29]'),
#  Text(0.1418867924528302, 0.82, 'x[0] <= -0.948\ngini = 0.22\nsamples = 33\nvalue = [2, 0, 2, 29]'),
#  Text(0.13886792452830188, 0.78, 'x[1] <= 2.502\ngini = 0.174\nsamples = 32\nvalue = [1, 0, 2, 29]'),
#  Text(0.1328301886792453, 0.74, 'x[1] <= 1.66\ngini = 0.069\nsamples = 28\nvalue = [1, 0, 0, 27]'),
#  Text(0.129811320754717, 0.7, 'x[1] <= 1.639\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]'),
#  Text(0.12679245283018867, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.1328301886792453, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.13584905660377358, 0.7, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 0, 25]'),
#  Text(0.1449056603773585, 0.74, 'x[0] <= -1.258\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.1418867924528302, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.1479245283018868, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.1449056603773585, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.1479245283018868, 0.82, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0]'),
#  Text(0.529901094256707, 0.94, 'x[1] <= -0.935\ngini = 0.745\nsamples = 1322\nvalue = [317, 398, 336, 271]'),
#  Text(0.19377358490566038, 0.9, 'x[1] <= -1.774\ngini = 0.608\nsamples = 228\nvalue = [109, 87, 2, 30]'),
#  Text(0.15849056603773584, 0.86, 'x[1] <= -2.827\ngini = 0.465\nsamples = 98\nvalue = [65, 3, 0, 30]'),
#  Text(0.15547169811320755, 0.82, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24]'),
#  Text(0.16150943396226414, 0.82, 'x[0] <= -0.458\ngini = 0.22\nsamples = 74\nvalue = [65, 3, 0, 6]'),
#  Text(0.15396226415094338, 0.78, 'x[1] <= -2.256\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.1509433962264151, 0.74, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.1569811320754717, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.16905660377358492, 0.78, 'x[1] <= -2.634\ngini = 0.163\nsamples = 69\nvalue = [63, 3, 0, 3]'),
#  Text(0.1630188679245283, 0.74, 'x[0] <= 0.507\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 0, 3]'),
#  Text(0.16, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.1660377358490566, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]'),
#  Text(0.1750943396226415, 0.74, 'x[1] <= -1.867\ngini = 0.094\nsamples = 61\nvalue = [58, 3, 0, 0]'),
#  Text(0.1720754716981132, 0.7, 'gini = 0.0\nsamples = 49\nvalue = [49, 0, 0, 0]'),
#  Text(0.1781132075471698, 0.7, 'x[1] <= -1.864\ngini = 0.375\nsamples = 12\nvalue = [9, 3, 0, 0]'),
#  Text(0.1750943396226415, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.1811320754716981, 0.66, 'x[0] <= 0.669\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0, 0]'),
#  Text(0.1781132075471698, 0.62, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.18415094339622642, 0.62, 'x[0] <= 1.89\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0]'),
#  Text(0.1811320754716981, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.18716981132075472, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.22905660377358492, 0.86, 'x[0] <= 2.794\ngini = 0.468\nsamples = 130\nvalue = [44, 84, 2, 0]'),
#  Text(0.21660377358490565, 0.82, 'x[0] <= -0.297\ngini = 0.32\nsamples = 103\nvalue = [18, 83, 2, 0]'),
#  Text(0.2037735849056604, 0.78, 'x[1] <= -1.021\ngini = 0.375\nsamples = 16\nvalue = [12, 4, 0, 0]'),
#  Text(0.19622641509433963, 0.74, 'x[0] <= -0.383\ngini = 0.26\nsamples = 13\nvalue = [11, 2, 0, 0]'),
#  Text(0.19018867924528302, 0.7, 'x[1] <= -1.311\ngini = 0.165\nsamples = 11\nvalue = [10, 1, 0, 0]'),
#  Text(0.18716981132075472, 0.66, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]'),
#  Text(0.1932075471698113, 0.66, 'x[1] <= -1.173\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.19018867924528302, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.19622641509433963, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.20226415094339623, 0.7, 'x[0] <= -0.358\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.19924528301886793, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.20528301886792452, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.21132075471698114, 0.74, 'x[0] <= -0.746\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]'),
#  Text(0.20830188679245282, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.21433962264150944, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.22943396226415094, 0.78, 'x[1] <= -1.523\ngini = 0.17\nsamples = 87\nvalue = [6, 79, 2, 0]'),
#  Text(0.22339622641509435, 0.74, 'x[0] <= 0.134\ngini = 0.346\nsamples = 27\nvalue = [6, 21, 0, 0]'),
#  Text(0.22037735849056603, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.22641509433962265, 0.7, 'x[0] <= 2.424\ngini = 0.219\nsamples = 24\nvalue = [3, 21, 0, 0]'),
#  Text(0.22339622641509435, 0.66, 'gini = 0.0\nsamples = 20\nvalue = [0, 20, 0, 0]'),
#  Text(0.22943396226415094, 0.66, 'x[1] <= -1.658\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0]'),
#  Text(0.22641509433962265, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.23245283018867924, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.23547169811320753, 0.74, 'x[1] <= -1.064\ngini = 0.064\nsamples = 60\nvalue = [0, 58, 2, 0]'),
#  Text(0.23245283018867924, 0.7, 'gini = 0.0\nsamples = 46\nvalue = [0, 46, 0, 0]'),
#  Text(0.23849056603773586, 0.7, 'x[1] <= -1.058\ngini = 0.245\nsamples = 14\nvalue = [0, 12, 2, 0]'),
#  Text(0.23547169811320753, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.24150943396226415, 0.66, 'x[1] <= -0.992\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1, 0]'),
#  Text(0.23849056603773586, 0.62, 'x[1] <= -1.006\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]'),
#  Text(0.23547169811320753, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.24150943396226415, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.24452830188679245, 0.62, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.24150943396226415, 0.82, 'x[1] <= -1.022\ngini = 0.071\nsamples = 27\nvalue = [26, 1, 0, 0]'),
#  Text(0.23849056603773586, 0.78, 'gini = 0.0\nsamples = 25\nvalue = [25, 0, 0, 0]'),
#  Text(0.24452830188679245, 0.78, 'x[0] <= 3.572\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.24150943396226415, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.24754716981132074, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8660286036077536, 0.9, 'x[0] <= 2.861\ngini = 0.741\nsamples = 1094\nvalue = [208, 311, 334, 241]'),
#  Text(0.7486609808004128, 0.86, 'x[0] <= 1.734\ngini = 0.738\nsamples = 1002\nvalue = [178, 249, 334, 241]'),
#  Text(0.5635483766951651, 0.82, 'x[1] <= 0.223\ngini = 0.748\nsamples = 841\nvalue = [178, 209, 227, 227]'),
#  Text(0.29954009433962264, 0.78, 'x[0] <= -0.042\ngini = 0.613\nsamples = 232\nvalue = [11, 50, 128, 43]'),
#  Text(0.270188679245283, 0.74, 'x[1] <= 0.058\ngini = 0.322\nsamples = 52\nvalue = [2, 42, 8, 0]'),
#  Text(0.259622641509434, 0.7, 'x[0] <= -0.782\ngini = 0.189\nsamples = 39\nvalue = [2, 35, 2, 0]'),
#  Text(0.25358490566037734, 0.66, 'x[1] <= -0.28\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]'),
#  Text(0.25056603773584907, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.25660377358490566, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.2656603773584906, 0.66, 'x[1] <= -0.24\ngini = 0.108\nsamples = 35\nvalue = [0, 33, 2, 0]'),
#  Text(0.26264150943396225, 0.62, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0, 0]'),
#  Text(0.26867924528301884, 0.62, 'x[1] <= -0.183\ngini = 0.32\nsamples = 10\nvalue = [0, 8, 2, 0]'),
#  Text(0.2656603773584906, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.27169811320754716, 0.58, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.2807547169811321, 0.7, 'x[0] <= -0.28\ngini = 0.497\nsamples = 13\nvalue = [0, 7, 6, 0]'),
#  Text(0.27773584905660376, 0.66, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]'),
#  Text(0.2837735849056604, 0.66, 'x[1] <= 0.08\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0]'),
#  Text(0.2807547169811321, 0.62, 'x[1] <= 0.075\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.27773584905660376, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.2837735849056604, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.28679245283018867, 0.62, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.3288915094339623, 0.74, 'x[1] <= -0.311\ngini = 0.494\nsamples = 180\nvalue = [9, 8, 120, 43]'),
#  Text(0.2988679245283019, 0.7, 'x[0] <= 0.246\ngini = 0.14\nsamples = 66\nvalue = [0, 5, 61, 0]'),
#  Text(0.2958490566037736, 0.66, 'x[0] <= 0.172\ngini = 0.5\nsamples = 10\nvalue = [0, 5, 5, 0]'),
#  Text(0.29283018867924526, 0.62, 'x[1] <= -0.534\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5, 0]'),
#  Text(0.289811320754717, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.2958490566037736, 0.58, 'x[1] <= -0.448\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]'),
#  Text(0.29283018867924526, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.2988679245283019, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.2988679245283019, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.3018867924528302, 0.66, 'gini = 0.0\nsamples = 56\nvalue = [0, 0, 56, 0]'),
#  Text(0.35891509433962265, 0.7, 'x[0] <= 0.28\ngini = 0.583\nsamples = 114\nvalue = [9, 3, 59, 43]'),
#  Text(0.3139622641509434, 0.66, 'x[0] <= 0.119\ngini = 0.263\nsamples = 27\nvalue = [0, 2, 23, 2]'),
#  Text(0.3109433962264151, 0.62, 'x[0] <= 0.113\ngini = 0.473\nsamples = 13\nvalue = [0, 2, 9, 2]'),
#  Text(0.30792452830188677, 0.58, 'x[0] <= 0.026\ngini = 0.403\nsamples = 12\nvalue = [0, 2, 9, 1]'),
#  Text(0.3049056603773585, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.3109433962264151, 0.54, 'x[0] <= 0.093\ngini = 0.571\nsamples = 7\nvalue = [0, 2, 4, 1]'),
#  Text(0.30792452830188677, 0.5, 'x[0] <= 0.036\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 1, 1]'),
#  Text(0.3049056603773585, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3109433962264151, 0.46, 'x[0] <= 0.062\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.30792452830188677, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.3139622641509434, 0.42, 'x[1] <= -0.246\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.3109433962264151, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.3169811320754717, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.3139622641509434, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.3139622641509434, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3169811320754717, 0.62, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]'),
#  Text(0.4038679245283019, 0.66, 'x[1] <= 0.085\ngini = 0.596\nsamples = 87\nvalue = [9, 1, 36, 41]'),
#  Text(0.3790566037735849, 0.62, 'x[0] <= 1.287\ngini = 0.499\nsamples = 55\nvalue = [0, 0, 26, 29]'),
#  Text(0.36566037735849055, 0.58, 'x[0] <= 0.946\ngini = 0.48\nsamples = 45\nvalue = [0, 0, 18, 27]'),
#  Text(0.3479245283018868, 0.54, 'x[1] <= -0.199\ngini = 0.5\nsamples = 33\nvalue = [0, 0, 17, 16]'),
#  Text(0.3290566037735849, 0.5, 'x[0] <= 0.457\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3]'),
#  Text(0.3260377358490566, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3320754716981132, 0.46, 'x[0] <= 0.923\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2]'),
#  Text(0.3260377358490566, 0.42, 'x[1] <= -0.234\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1]'),
#  Text(0.3230188679245283, 0.38, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.3290566037735849, 0.38, 'x[1] <= -0.224\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1]'),
#  Text(0.3260377358490566, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3320754716981132, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.33811320754716984, 0.42, 'x[1] <= -0.295\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.3350943396226415, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.3411320754716981, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.3667924528301887, 0.5, 'x[0] <= 0.699\ngini = 0.455\nsamples = 20\nvalue = [0, 0, 7, 13]'),
#  Text(0.3562264150943396, 0.46, 'x[0] <= 0.604\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 6, 7]'),
#  Text(0.350188679245283, 0.42, 'x[1] <= -0.119\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6]'),
#  Text(0.3471698113207547, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.35320754716981134, 0.38, 'x[1] <= -0.099\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4]'),
#  Text(0.350188679245283, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.3562264150943396, 0.34, 'x[0] <= 0.365\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4]'),
#  Text(0.35320754716981134, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.35924528301886793, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.3622641509433962, 0.42, 'x[0] <= 0.678\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1]'),
#  Text(0.35924528301886793, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.3652830188679245, 0.38, 'x[0] <= 0.695\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.3622641509433962, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.36830188679245285, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.37735849056603776, 0.46, 'x[1] <= -0.137\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6]'),
#  Text(0.37433962264150944, 0.42, 'x[1] <= -0.168\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.3713207547169811, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.37735849056603776, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.38037735849056603, 0.42, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]'),
#  Text(0.38339622641509435, 0.54, 'x[0] <= 1.217\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11]'),
#  Text(0.38037735849056603, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10]'),
#  Text(0.3864150943396226, 0.5, 'x[1] <= -0.159\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.38339622641509435, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.38943396226415095, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.39245283018867927, 0.58, 'x[1] <= -0.294\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2]'),
#  Text(0.38943396226415095, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.39547169811320754, 0.54, 'x[1] <= 0.015\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1]'),
#  Text(0.39245283018867927, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]'),
#  Text(0.39849056603773586, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.4286792452830189, 0.62, 'x[0] <= 0.908\ngini = 0.682\nsamples = 32\nvalue = [9, 1, 10, 12]'),
#  Text(0.41358490566037737, 0.58, 'x[0] <= 0.484\ngini = 0.685\nsamples = 21\nvalue = [7, 1, 8, 5]'),
#  Text(0.4075471698113208, 0.54, 'x[1] <= 0.172\ngini = 0.571\nsamples = 7\nvalue = [2, 0, 1, 4]'),
#  Text(0.40452830188679245, 0.5, 'x[0] <= 0.377\ngini = 0.625\nsamples = 4\nvalue = [2, 0, 1, 1]'),
#  Text(0.40150943396226413, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.4075471698113208, 0.46, 'x[1] <= 0.111\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.40452830188679245, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.41056603773584904, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.41056603773584904, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.41962264150943396, 0.54, 'x[1] <= 0.109\ngini = 0.612\nsamples = 14\nvalue = [5, 1, 7, 1]'),
#  Text(0.41660377358490563, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.4226415094339623, 0.5, 'x[0] <= 0.852\ngini = 0.545\nsamples = 11\nvalue = [2, 1, 7, 1]'),
#  Text(0.41962264150943396, 0.46, 'x[0] <= 0.709\ngini = 0.48\nsamples = 10\nvalue = [1, 1, 7, 1]'),
#  Text(0.41660377358490563, 0.42, 'x[0] <= 0.653\ngini = 0.667\nsamples = 6\nvalue = [1, 1, 3, 1]'),
#  Text(0.41056603773584904, 0.38, 'x[1] <= 0.138\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0]'),
#  Text(0.4075471698113208, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.41358490566037737, 0.34, 'x[0] <= 0.559\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]'),
#  Text(0.41056603773584904, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.41660377358490563, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.4226415094339623, 0.38, 'x[0] <= 0.689\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]'),
#  Text(0.41962264150943396, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.42566037735849055, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.4226415094339623, 0.42, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.42566037735849055, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4437735849056604, 0.58, 'x[1] <= 0.17\ngini = 0.529\nsamples = 11\nvalue = [2, 0, 2, 7]'),
#  Text(0.4377358490566038, 0.54, 'x[1] <= 0.119\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6]'),
#  Text(0.43471698113207546, 0.5, 'x[1] <= 0.106\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.4316981132075472, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.4377358490566038, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.44075471698113206, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.44981132075471697, 0.54, 'x[0] <= 0.954\ngini = 0.625\nsamples = 4\nvalue = [2, 0, 1, 1]'),
#  Text(0.4467924528301887, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.4528301886792453, 0.5, 'x[0] <= 1.421\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.44981132075471697, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.45584905660377356, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8275566590507075, 0.78, 'x[1] <= 2.896\ngini = 0.739\nsamples = 609\nvalue = [167, 159, 99, 184]'),
#  Text(0.774358601120283, 0.74, 'x[0] <= 0.899\ngini = 0.715\nsamples = 533\nvalue = [167, 128, 54, 184]'),
#  Text(0.7016417305424528, 0.7, 'x[1] <= 2.042\ngini = 0.712\nsamples = 380\nvalue = [133, 126, 41, 80]'),
#  Text(0.6493211969339623, 0.66, 'x[1] <= 1.045\ngini = 0.678\nsamples = 337\nvalue = [133, 126, 40, 38]'),
#  Text(0.5537367334905661, 0.62, 'x[0] <= 0.029\ngini = 0.665\nsamples = 222\nvalue = [41, 111, 40, 30]'),
#  Text(0.4758490566037736, 0.58, 'x[0] <= -0.747\ngini = 0.305\nsamples = 74\nvalue = [6, 61, 7, 0]'),
#  Text(0.4618867924528302, 0.54, 'x[1] <= 0.604\ngini = 0.494\nsamples = 9\nvalue = [4, 5, 0, 0]'),
#  Text(0.4588679245283019, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.4649056603773585, 0.5, 'x[0] <= -0.827\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0, 0]'),
#  Text(0.4618867924528302, 0.46, 'x[1] <= 0.849\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.4588679245283019, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.4649056603773585, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4679245283018868, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.489811320754717, 0.54, 'x[0] <= -0.314\ngini = 0.245\nsamples = 65\nvalue = [2, 56, 7, 0]'),
#  Text(0.4769811320754717, 0.5, 'x[1] <= 0.865\ngini = 0.056\nsamples = 35\nvalue = [1, 34, 0, 0]'),
#  Text(0.4739622641509434, 0.46, 'gini = 0.0\nsamples = 27\nvalue = [0, 27, 0, 0]'),
#  Text(0.48, 0.46, 'x[1] <= 0.868\ngini = 0.219\nsamples = 8\nvalue = [1, 7, 0, 0]'),
#  Text(0.4769811320754717, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4830188679245283, 0.42, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]'),
#  Text(0.5026415094339622, 0.5, 'x[1] <= 0.395\ngini = 0.407\nsamples = 30\nvalue = [1, 22, 7, 0]'),
#  Text(0.4920754716981132, 0.46, 'x[1] <= 0.272\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4, 0]'),
#  Text(0.4890566037735849, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.4950943396226415, 0.42, 'x[1] <= 0.332\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]'),
#  Text(0.4920754716981132, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.4981132075471698, 0.38, 'x[0] <= -0.143\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.4950943396226415, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5011320754716981, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5132075471698113, 0.46, 'x[0] <= -0.295\ngini = 0.288\nsamples = 24\nvalue = [1, 20, 3, 0]'),
#  Text(0.5071698113207547, 0.42, 'x[1] <= 0.888\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.5041509433962265, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.510188679245283, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.519245283018868, 0.42, 'x[0] <= -0.157\ngini = 0.236\nsamples = 22\nvalue = [0, 19, 3, 0]'),
#  Text(0.5162264150943396, 0.38, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.5222641509433962, 0.38, 'x[0] <= -0.059\ngini = 0.337\nsamples = 14\nvalue = [0, 11, 3, 0]'),
#  Text(0.5162264150943396, 0.34, 'x[1] <= 0.474\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.5132075471698113, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.519245283018868, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5283018867924528, 0.34, 'x[1] <= 0.848\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 1, 0]'),
#  Text(0.5252830188679245, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0]'),
#  Text(0.5313207547169811, 0.3, 'x[0] <= -0.004\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.5283018867924528, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5343396226415095, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6316244103773585, 0.58, 'x[0] <= 0.545\ngini = 0.739\nsamples = 148\nvalue = [35, 50, 33, 30]'),
#  Text(0.5831544811320755, 0.54, 'x[1] <= 0.232\ngini = 0.703\nsamples = 89\nvalue = [13, 38, 22, 16]'),
#  Text(0.5801356132075471, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.5861733490566038, 0.5, 'x[1] <= 0.97\ngini = 0.694\nsamples = 86\nvalue = [13, 38, 22, 13]'),
#  Text(0.5678891509433962, 0.46, 'x[0] <= 0.086\ngini = 0.711\nsamples = 78\nvalue = [12, 31, 22, 13]'),
#  Text(0.540377358490566, 0.42, 'x[0] <= 0.063\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6, 0]'),
#  Text(0.5373584905660377, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.5433962264150943, 0.38, 'x[0] <= 0.078\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0]'),
#  Text(0.540377358490566, 0.34, 'x[1] <= 0.415\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.5373584905660377, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5433962264150943, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.5464150943396227, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5954009433962264, 0.42, 'x[0] <= 0.473\ngini = 0.712\nsamples = 70\nvalue = [12, 29, 16, 13]'),
#  Text(0.572311320754717, 0.38, 'x[0] <= 0.229\ngini = 0.691\nsamples = 59\nvalue = [11, 27, 9, 12]'),
#  Text(0.5524528301886793, 0.34, 'x[1] <= 0.708\ngini = 0.574\nsamples = 18\nvalue = [1, 10, 1, 6]'),
#  Text(0.549433962264151, 0.3, 'x[1] <= 0.629\ngini = 0.627\nsamples = 13\nvalue = [1, 5, 1, 6]'),
#  Text(0.5433962264150943, 0.26, 'x[0] <= 0.169\ngini = 0.568\nsamples = 9\nvalue = [1, 5, 0, 3]'),
#  Text(0.540377358490566, 0.22, 'x[0] <= 0.122\ngini = 0.611\nsamples = 6\nvalue = [1, 2, 0, 3]'),
#  Text(0.5373584905660377, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.5433962264150943, 0.18, 'x[1] <= 0.594\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]'),
#  Text(0.540377358490566, 0.14, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.5464150943396227, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5464150943396227, 0.22, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.5554716981132075, 0.26, 'x[1] <= 0.671\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3]'),
#  Text(0.5524528301886793, 0.22, 'x[0] <= 0.123\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.549433962264151, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5554716981132075, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5584905660377358, 0.22, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.5554716981132075, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.5921698113207547, 0.34, 'x[1] <= 0.834\ngini = 0.709\nsamples = 41\nvalue = [10, 17, 8, 6]'),
#  Text(0.5809433962264151, 0.3, 'x[1] <= 0.358\ngini = 0.685\nsamples = 37\nvalue = [9, 17, 5, 6]'),
#  Text(0.5675471698113208, 0.26, 'x[0] <= 0.399\ngini = 0.406\nsamples = 8\nvalue = [0, 6, 1, 1]'),
#  Text(0.5645283018867925, 0.22, 'x[1] <= 0.301\ngini = 0.245\nsamples = 7\nvalue = [0, 6, 1, 0]'),
#  Text(0.5615094339622642, 0.18, 'x[0] <= 0.324\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.5584905660377358, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5645283018867925, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5675471698113208, 0.18, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.570566037735849, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5943396226415094, 0.26, 'x[0] <= 0.362\ngini = 0.711\nsamples = 29\nvalue = [9, 11, 4, 5]'),
#  Text(0.5833962264150944, 0.22, 'x[1] <= 0.563\ngini = 0.721\nsamples = 21\nvalue = [8, 5, 3, 5]'),
#  Text(0.5735849056603773, 0.18, 'x[0] <= 0.321\ngini = 0.694\nsamples = 12\nvalue = [5, 1, 3, 3]'),
#  Text(0.570566037735849, 0.14, 'x[1] <= 0.49\ngini = 0.716\nsamples = 9\nvalue = [2, 1, 3, 3]'),
#  Text(0.5630188679245283, 0.1, 'x[0] <= 0.279\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 2, 3]'),
#  Text(0.5569811320754717, 0.06, 'x[1] <= 0.391\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]'),
#  Text(0.5539622641509434, 0.02, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.56, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5690566037735849, 0.06, 'x[1] <= 0.471\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.5660377358490566, 0.02, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5720754716981132, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5781132075471698, 0.1, 'x[1] <= 0.528\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.5750943396226416, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5811320754716981, 0.06, 'x[0] <= 0.246\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]'),
#  Text(0.5781132075471698, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5841509433962264, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5766037735849057, 0.14, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.5932075471698113, 0.18, 'x[1] <= 0.632\ngini = 0.642\nsamples = 9\nvalue = [3, 4, 0, 2]'),
#  Text(0.5871698113207547, 0.14, 'x[0] <= 0.342\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1]'),
#  Text(0.5841509433962264, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.5901886792452831, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5992452830188679, 0.14, 'x[0] <= 0.322\ngini = 0.56\nsamples = 5\nvalue = [3, 1, 0, 1]'),
#  Text(0.5962264150943396, 0.1, 'x[0] <= 0.288\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0]'),
#  Text(0.5932075471698113, 0.06, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.5992452830188679, 0.06, 'x[0] <= 0.305\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.5962264150943396, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6022641509433962, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6022641509433962, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6052830188679246, 0.22, 'x[1] <= 0.411\ngini = 0.406\nsamples = 8\nvalue = [1, 6, 1, 0]'),
#  Text(0.6022641509433962, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6083018867924528, 0.18, 'x[0] <= 0.442\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0, 0]'),
#  Text(0.6052830188679246, 0.14, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.6113207547169811, 0.14, 'x[1] <= 0.595\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.6083018867924528, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6143396226415094, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6033962264150944, 0.3, 'x[0] <= 0.422\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0]'),
#  Text(0.6003773584905661, 0.26, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.6064150943396226, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6184905660377359, 0.38, 'x[1] <= 0.446\ngini = 0.545\nsamples = 11\nvalue = [1, 2, 7, 1]'),
#  Text(0.6124528301886792, 0.34, 'x[0] <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 1]'),
#  Text(0.6094339622641509, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6154716981132076, 0.3, 'x[1] <= 0.401\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.6124528301886792, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6184905660377359, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6245283018867924, 0.34, 'x[1] <= 0.715\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6, 0]'),
#  Text(0.6215094339622641, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.6275471698113207, 0.3, 'x[0] <= 0.479\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0]'),
#  Text(0.6245283018867924, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6305660377358491, 0.26, 'x[1] <= 0.734\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.6275471698113207, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6335849056603774, 0.22, 'x[0] <= 0.489\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.6305660377358491, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6366037735849056, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6044575471698114, 0.46, 'x[1] <= 1.026\ngini = 0.219\nsamples = 8\nvalue = [1, 7, 0, 0]'),
#  Text(0.601438679245283, 0.42, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]'),
#  Text(0.6074764150943396, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6800943396226415, 0.54, 'x[1] <= 0.861\ngini = 0.729\nsamples = 59\nvalue = [22, 12, 11, 14]'),
#  Text(0.6605660377358491, 0.5, 'x[0] <= 0.636\ngini = 0.746\nsamples = 48\nvalue = [13, 11, 10, 14]'),
#  Text(0.6366037735849056, 0.46, 'x[0] <= 0.567\ngini = 0.58\nsamples = 10\nvalue = [1, 0, 4, 5]'),
#  Text(0.6305660377358491, 0.42, 'x[1] <= 0.471\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]'),
#  Text(0.6275471698113207, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6335849056603774, 0.38, 'x[0] <= 0.549\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.6305660377358491, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6366037735849056, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6426415094339623, 0.42, 'x[0] <= 0.577\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3]'),
#  Text(0.6396226415094339, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6456603773584906, 0.38, 'x[1] <= 0.246\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3]'),
#  Text(0.6426415094339623, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6486792452830189, 0.34, 'x[1] <= 0.678\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3]'),
#  Text(0.6456603773584906, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.6516981132075472, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6845283018867925, 0.46, 'x[0] <= 0.873\ngini = 0.735\nsamples = 38\nvalue = [12, 11, 6, 9]'),
#  Text(0.6815094339622642, 0.42, 'x[1] <= 0.824\ngini = 0.721\nsamples = 36\nvalue = [12, 11, 4, 9]'),
#  Text(0.6784905660377358, 0.38, 'x[1] <= 0.554\ngini = 0.721\nsamples = 34\nvalue = [12, 9, 4, 9]'),
#  Text(0.6607547169811321, 0.34, 'x[1] <= 0.497\ngini = 0.676\nsamples = 15\nvalue = [4, 7, 2, 2]'),
#  Text(0.6577358490566038, 0.3, 'x[0] <= 0.829\ngini = 0.722\nsamples = 12\nvalue = [4, 4, 2, 2]'),
#  Text(0.6547169811320754, 0.26, 'x[0] <= 0.667\ngini = 0.72\nsamples = 10\nvalue = [2, 4, 2, 2]'),
#  Text(0.6471698113207547, 0.22, 'x[0] <= 0.658\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]'),
#  Text(0.6441509433962264, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.650188679245283, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.6622641509433962, 0.22, 'x[0] <= 0.683\ngini = 0.653\nsamples = 7\nvalue = [0, 3, 2, 2]'),
#  Text(0.6562264150943397, 0.18, 'x[0] <= 0.675\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]'),
#  Text(0.6532075471698113, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.659245283018868, 0.14, 'x[1] <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]'),
#  Text(0.6562264150943397, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6622641509433962, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6683018867924528, 0.18, 'x[1] <= 0.264\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]'),
#  Text(0.6652830188679245, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6713207547169812, 0.14, 'x[1] <= 0.33\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.6683018867924528, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6743396226415095, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6607547169811321, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.6637735849056604, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.6962264150943396, 0.34, 'x[0] <= 0.831\ngini = 0.665\nsamples = 19\nvalue = [8, 2, 2, 7]'),
#  Text(0.6879245283018868, 0.3, 'x[1] <= 0.666\ngini = 0.663\nsamples = 14\nvalue = [7, 2, 2, 3]'),
#  Text(0.680377358490566, 0.26, 'x[1] <= 0.618\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 3]'),
#  Text(0.6773584905660377, 0.22, 'x[0] <= 0.732\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]'),
#  Text(0.6743396226415095, 0.18, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.680377358490566, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6833962264150943, 0.22, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.6954716981132075, 0.26, 'x[0] <= 0.787\ngini = 0.625\nsamples = 8\nvalue = [4, 2, 2, 0]'),
#  Text(0.6924528301886792, 0.22, 'x[0] <= 0.713\ngini = 0.64\nsamples = 5\nvalue = [1, 2, 2, 0]'),
#  Text(0.6864150943396227, 0.18, 'x[0] <= 0.702\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.6833962264150943, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.689433962264151, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6984905660377358, 0.18, 'x[1] <= 0.695\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.6954716981132075, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7015094339622642, 0.14, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6984905660377358, 0.22, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.7045283018867925, 0.3, 'x[0] <= 0.871\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 4]'),
#  Text(0.7015094339622642, 0.26, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.7075471698113207, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6845283018867925, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.6875471698113208, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.699622641509434, 0.5, 'x[1] <= 1.013\ngini = 0.314\nsamples = 11\nvalue = [9, 1, 1, 0]'),
#  Text(0.6966037735849057, 0.46, 'x[1] <= 0.91\ngini = 0.18\nsamples = 10\nvalue = [9, 0, 1, 0]'),
#  Text(0.6935849056603773, 0.42, 'x[1] <= 0.897\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.690566037735849, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.6966037735849057, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.699622641509434, 0.42, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]'),
#  Text(0.7026415094339623, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7449056603773585, 0.62, 'x[1] <= 1.272\ngini = 0.338\nsamples = 115\nvalue = [92, 15, 0, 8]'),
#  Text(0.7252830188679246, 0.58, 'x[0] <= 0.033\ngini = 0.454\nsamples = 43\nvalue = [28, 15, 0, 0]'),
#  Text(0.7177358490566038, 0.54, 'x[1] <= 1.213\ngini = 0.255\nsamples = 20\nvalue = [17, 3, 0, 0]'),
#  Text(0.7116981132075472, 0.5, 'x[1] <= 1.095\ngini = 0.124\nsamples = 15\nvalue = [14, 1, 0, 0]'),
#  Text(0.7086792452830188, 0.46, 'x[1] <= 1.07\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]'),
#  Text(0.7056603773584905, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7116981132075472, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7147169811320755, 0.46, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]'),
#  Text(0.7237735849056603, 0.5, 'x[0] <= -0.356\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0]'),
#  Text(0.720754716981132, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.7267924528301887, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.7328301886792453, 0.54, 'x[0] <= 0.259\ngini = 0.499\nsamples = 23\nvalue = [11, 12, 0, 0]'),
#  Text(0.729811320754717, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]'),
#  Text(0.7358490566037735, 0.5, 'x[1] <= 1.263\ngini = 0.43\nsamples = 16\nvalue = [11, 5, 0, 0]'),
#  Text(0.7328301886792453, 0.46, 'x[1] <= 1.077\ngini = 0.391\nsamples = 15\nvalue = [11, 4, 0, 0]'),
#  Text(0.7267924528301887, 0.42, 'x[1] <= 1.054\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]'),
#  Text(0.7237735849056603, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.729811320754717, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.7388679245283019, 0.42, 'x[1] <= 1.146\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0, 0]'),
#  Text(0.7358490566037735, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.7418867924528302, 0.38, 'x[1] <= 1.153\ngini = 0.408\nsamples = 7\nvalue = [5, 2, 0, 0]'),
#  Text(0.7388679245283019, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7449056603773585, 0.34, 'x[0] <= 0.633\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0, 0]'),
#  Text(0.7418867924528302, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.7479245283018868, 0.3, 'x[0] <= 0.683\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]'),
#  Text(0.7449056603773585, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7509433962264151, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7388679245283019, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.7645283018867924, 0.58, 'x[1] <= 1.929\ngini = 0.198\nsamples = 72\nvalue = [64, 0, 0, 8]'),
#  Text(0.7509433962264151, 0.54, 'x[1] <= 1.632\ngini = 0.094\nsamples = 61\nvalue = [58, 0, 0, 3]'),
#  Text(0.7479245283018868, 0.5, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0, 0]'),
#  Text(0.7539622641509434, 0.5, 'x[1] <= 1.653\ngini = 0.266\nsamples = 19\nvalue = [16, 0, 0, 3]'),
#  Text(0.7509433962264151, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7569811320754717, 0.46, 'x[0] <= -0.736\ngini = 0.198\nsamples = 18\nvalue = [16, 0, 0, 2]'),
#  Text(0.7509433962264151, 0.42, 'x[0] <= -0.821\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.7479245283018868, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.7539622641509434, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7630188679245283, 0.42, 'x[0] <= 0.518\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 0, 1]'),
#  Text(0.76, 0.38, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]'),
#  Text(0.7660377358490567, 0.38, 'x[0] <= 0.714\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]'),
#  Text(0.7630188679245283, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7690566037735849, 0.34, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.7781132075471698, 0.54, 'x[0] <= 0.43\ngini = 0.496\nsamples = 11\nvalue = [6, 0, 0, 5]'),
#  Text(0.7750943396226415, 0.5, 'x[1] <= 1.971\ngini = 0.444\nsamples = 9\nvalue = [6, 0, 0, 3]'),
#  Text(0.7720754716981132, 0.46, 'x[0] <= -0.369\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.7690566037735849, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.7750943396226415, 0.42, 'x[1] <= 1.938\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.7720754716981132, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7781132075471698, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7781132075471698, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.7811320754716982, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.7539622641509434, 0.66, 'x[0] <= 0.763\ngini = 0.045\nsamples = 43\nvalue = [0, 0, 1, 42]'),
#  Text(0.7509433962264151, 0.62, 'gini = 0.0\nsamples = 42\nvalue = [0, 0, 0, 42]'),
#  Text(0.7569811320754717, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8470754716981133, 0.7, 'x[1] <= 2.506\ngini = 0.481\nsamples = 153\nvalue = [34, 2, 13, 104]'),
#  Text(0.8345283018867925, 0.66, 'x[0] <= 1.303\ngini = 0.41\nsamples = 140\nvalue = [34, 2, 2, 102]'),
#  Text(0.8184905660377358, 0.62, 'x[1] <= 1.668\ngini = 0.495\nsamples = 91\nvalue = [34, 2, 0, 55]'),
#  Text(0.8045283018867925, 0.58, 'x[1] <= 0.82\ngini = 0.527\nsamples = 70\nvalue = [33, 2, 0, 35]'),
#  Text(0.7962264150943397, 0.54, 'x[1] <= 0.593\ngini = 0.491\nsamples = 34\nvalue = [10, 2, 0, 22]'),
#  Text(0.7932075471698113, 0.5, 'x[1] <= 0.552\ngini = 0.541\nsamples = 28\nvalue = [10, 2, 0, 16]'),
#  Text(0.790188679245283, 0.46, 'x[0] <= 1.265\ngini = 0.521\nsamples = 26\nvalue = [8, 2, 0, 16]'),
#  Text(0.7871698113207547, 0.42, 'x[0] <= 1.172\ngini = 0.486\nsamples = 24\nvalue = [6, 2, 0, 16]'),
#  Text(0.7841509433962264, 0.38, 'x[0] <= 1.147\ngini = 0.568\nsamples = 18\nvalue = [6, 2, 0, 10]'),
#  Text(0.7811320754716982, 0.34, 'x[1] <= 0.478\ngini = 0.531\nsamples = 16\nvalue = [4, 2, 0, 10]'),
#  Text(0.7720754716981132, 0.3, 'x[1] <= 0.397\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 0, 5]'),
#  Text(0.7690566037735849, 0.26, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.7750943396226415, 0.26, 'x[1] <= 0.467\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]'),
#  Text(0.7720754716981132, 0.22, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.7781132075471698, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.790188679245283, 0.3, 'x[1] <= 0.508\ngini = 0.494\nsamples = 9\nvalue = [4, 0, 0, 5]'),
#  Text(0.7871698113207547, 0.26, 'x[0] <= 0.935\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]'),
#  Text(0.7841509433962264, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.790188679245283, 0.22, 'x[0] <= 1.057\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]'),
#  Text(0.7871698113207547, 0.18, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.7932075471698113, 0.18, 'x[0] <= 1.072\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.790188679245283, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7962264150943397, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.7932075471698113, 0.26, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.7871698113207547, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.790188679245283, 0.38, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.7932075471698113, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7962264150943397, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7992452830188679, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.8128301886792453, 0.54, 'x[1] <= 1.206\ngini = 0.461\nsamples = 36\nvalue = [23, 0, 0, 13]'),
#  Text(0.8052830188679245, 0.5, 'x[1] <= 1.013\ngini = 0.219\nsamples = 16\nvalue = [14, 0, 0, 2]'),
#  Text(0.8022641509433962, 0.46, 'x[1] <= 0.993\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 0, 2]'),
#  Text(0.7992452830188679, 0.42, 'x[0] <= 1.162\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1]'),
#  Text(0.7962264150943397, 0.38, 'x[1] <= 0.878\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.7932075471698113, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.7992452830188679, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.8022641509433962, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.8052830188679245, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.8083018867924529, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]'),
#  Text(0.820377358490566, 0.5, 'x[1] <= 1.285\ngini = 0.495\nsamples = 20\nvalue = [9, 0, 0, 11]'),
#  Text(0.8143396226415094, 0.46, 'x[0] <= 1.067\ngini = 0.278\nsamples = 6\nvalue = [1, 0, 0, 5]'),
#  Text(0.8113207547169812, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8173584905660377, 0.42, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]'),
#  Text(0.8264150943396227, 0.46, 'x[1] <= 1.306\ngini = 0.49\nsamples = 14\nvalue = [8, 0, 0, 6]'),
#  Text(0.8233962264150944, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.8294339622641509, 0.42, 'x[0] <= 1.266\ngini = 0.5\nsamples = 12\nvalue = [6, 0, 0, 6]'),
#  Text(0.8264150943396227, 0.38, 'x[1] <= 1.625\ngini = 0.48\nsamples = 10\nvalue = [4, 0, 0, 6]'),
#  Text(0.8233962264150944, 0.34, 'x[1] <= 1.561\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 0, 6]'),
#  Text(0.820377358490566, 0.3, 'x[1] <= 1.471\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.8173584905660377, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.8233962264150944, 0.26, 'x[0] <= 0.955\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.820377358490566, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8264150943396227, 0.22, 'x[1] <= 1.546\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]'),
#  Text(0.8233962264150944, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.8294339622641509, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8264150943396227, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.8294339622641509, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.8324528301886792, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.8324528301886792, 0.58, 'x[0] <= 0.951\ngini = 0.091\nsamples = 21\nvalue = [1, 0, 0, 20]'),
#  Text(0.8294339622641509, 0.54, 'x[0] <= 0.935\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]'),
#  Text(0.8264150943396227, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.8324528301886792, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8354716981132075, 0.54, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 17]'),
#  Text(0.850566037735849, 0.62, 'x[0] <= 1.727\ngini = 0.078\nsamples = 49\nvalue = [0, 0, 2, 47]'),
#  Text(0.8445283018867924, 0.58, 'x[1] <= 2.222\ngini = 0.042\nsamples = 47\nvalue = [0, 0, 1, 46]'),
#  Text(0.8415094339622642, 0.54, 'gini = 0.0\nsamples = 44\nvalue = [0, 0, 0, 44]'),
#  Text(0.8475471698113207, 0.54, 'x[1] <= 2.264\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.8445283018867924, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.850566037735849, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.8566037735849057, 0.58, 'x[1] <= 1.208\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.8535849056603774, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.859622641509434, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.859622641509434, 0.66, 'x[0] <= 1.085\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2]'),
#  Text(0.8566037735849057, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.8626415094339622, 0.62, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]'),
#  Text(0.8807547169811321, 0.74, 'x[1] <= 3.879\ngini = 0.483\nsamples = 76\nvalue = [0, 31, 45, 0]'),
#  Text(0.8777358490566037, 0.7, 'x[0] <= 1.137\ngini = 0.298\nsamples = 55\nvalue = [0, 10, 45, 0]'),
#  Text(0.8716981132075472, 0.66, 'x[1] <= 3.783\ngini = 0.05\nsamples = 39\nvalue = [0, 1, 38, 0]'),
#  Text(0.8686792452830189, 0.62, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35, 0]'),
#  Text(0.8747169811320755, 0.62, 'x[1] <= 3.813\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]'),
#  Text(0.8716981132075472, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.8777358490566037, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.8837735849056604, 0.66, 'x[1] <= 3.228\ngini = 0.492\nsamples = 16\nvalue = [0, 9, 7, 0]'),
#  Text(0.8807547169811321, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.8867924528301887, 0.62, 'x[1] <= 3.665\ngini = 0.375\nsamples = 12\nvalue = [0, 9, 3, 0]'),
#  Text(0.8837735849056604, 0.58, 'x[1] <= 3.654\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3, 0]'),
#  Text(0.8807547169811321, 0.54, 'x[0] <= 1.322\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2, 0]'),
#  Text(0.8777358490566037, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.8837735849056604, 0.5, 'x[0] <= 1.473\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.8807547169811321, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.8867924528301887, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.8867924528301887, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.889811320754717, 0.58, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.8837735849056604, 0.7, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0]'),
#  Text(0.9337735849056604, 0.82, 'x[1] <= 3.029\ngini = 0.489\nsamples = 161\nvalue = [0, 40, 107, 14]'),
#  Text(0.9098113207547169, 0.78, 'x[1] <= -0.522\ngini = 0.421\nsamples = 144\nvalue = [0, 24, 106, 14]'),
#  Text(0.8928301886792452, 0.74, 'x[1] <= -0.613\ngini = 0.231\nsamples = 15\nvalue = [0, 13, 2, 0]'),
#  Text(0.889811320754717, 0.7, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]'),
#  Text(0.8958490566037736, 0.7, 'x[0] <= 2.351\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2, 0]'),
#  Text(0.8928301886792452, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.8988679245283019, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.9267924528301886, 0.74, 'x[0] <= 2.033\ngini = 0.331\nsamples = 129\nvalue = [0, 11, 104, 14]'),
#  Text(0.9079245283018867, 0.7, 'x[1] <= 1.787\ngini = 0.46\nsamples = 39\nvalue = [0, 0, 25, 14]'),
#  Text(0.9049056603773585, 0.66, 'x[1] <= 0.574\ngini = 0.493\nsamples = 25\nvalue = [0, 0, 11, 14]'),
#  Text(0.8988679245283019, 0.62, 'x[1] <= 0.207\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3]'),
#  Text(0.8958490566037736, 0.58, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.9018867924528302, 0.58, 'x[1] <= 0.244\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3]'),
#  Text(0.8988679245283019, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.9049056603773585, 0.54, 'x[1] <= 0.38\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1]'),
#  Text(0.9018867924528302, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.9079245283018867, 0.5, 'x[0] <= 1.935\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.9049056603773585, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.9109433962264151, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9109433962264151, 0.62, 'x[0] <= 1.983\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11]'),
#  Text(0.9079245283018867, 0.58, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9]'),
#  Text(0.9139622641509434, 0.58, 'x[0] <= 2.004\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.9109433962264151, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9169811320754717, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.9109433962264151, 0.66, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]'),
#  Text(0.9456603773584905, 0.7, 'x[1] <= 2.662\ngini = 0.215\nsamples = 90\nvalue = [0, 11, 79, 0]'),
#  Text(0.9426415094339623, 0.66, 'x[0] <= 2.812\ngini = 0.15\nsamples = 86\nvalue = [0, 7, 79, 0]'),
#  Text(0.9320754716981132, 0.62, 'x[1] <= -0.248\ngini = 0.096\nsamples = 79\nvalue = [0, 4, 75, 0]'),
#  Text(0.9260377358490566, 0.58, 'x[1] <= -0.271\ngini = 0.469\nsamples = 8\nvalue = [0, 3, 5, 0]'),
#  Text(0.9230188679245283, 0.54, 'x[0] <= 2.612\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5, 0]'),
#  Text(0.92, 0.5, 'x[1] <= -0.35\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0]'),
#  Text(0.9169811320754717, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.9230188679245283, 0.46, 'x[1] <= -0.325\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.92, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9260377358490566, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.9260377358490566, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9290566037735849, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9381132075471698, 0.58, 'x[1] <= 0.246\ngini = 0.028\nsamples = 71\nvalue = [0, 1, 70, 0]'),
#  Text(0.9350943396226415, 0.54, 'x[1] <= 0.214\ngini = 0.133\nsamples = 14\nvalue = [0, 1, 13, 0]'),
#  Text(0.9320754716981132, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0]'),
#  Text(0.9381132075471698, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9411320754716981, 0.54, 'gini = 0.0\nsamples = 57\nvalue = [0, 0, 57, 0]'),
#  Text(0.9532075471698114, 0.62, 'x[1] <= 1.515\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4, 0]'),
#  Text(0.950188679245283, 0.58, 'x[0] <= 2.823\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]'),
#  Text(0.9471698113207547, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9532075471698114, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.9562264150943396, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.9486792452830188, 0.66, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.9577358490566038, 0.78, 'x[1] <= 3.228\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1, 0]'),
#  Text(0.9547169811320755, 0.74, 'x[1] <= 3.185\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0]'),
#  Text(0.9516981132075472, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.9577358490566038, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9607547169811321, 0.74, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0, 0]'),
#  Text(0.9833962264150944, 0.86, 'x[0] <= 3.741\ngini = 0.44\nsamples = 92\nvalue = [30, 62, 0, 0]'),
#  Text(0.9758490566037736, 0.82, 'x[1] <= -0.309\ngini = 0.172\nsamples = 63\nvalue = [6, 57, 0, 0]'),
#  Text(0.969811320754717, 0.78, 'x[0] <= 3.364\ngini = 0.494\nsamples = 9\nvalue = [5, 4, 0, 0]'),
#  Text(0.9667924528301887, 0.74, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.9728301886792453, 0.74, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]'),
#  Text(0.9818867924528302, 0.78, 'x[1] <= 0.014\ngini = 0.036\nsamples = 54\nvalue = [1, 53, 0, 0]'),
#  Text(0.9788679245283018, 0.74, 'x[1] <= -0.055\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0, 0]'),
#  Text(0.9758490566037736, 0.7, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]'),
#  Text(0.9818867924528302, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9849056603773585, 0.74, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0, 0]'),
#  Text(0.9909433962264151, 0.82, 'x[1] <= 0.599\ngini = 0.285\nsamples = 29\nvalue = [24, 5, 0, 0]'),
#  Text(0.9879245283018868, 0.78, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]'),
#  Text(0.9939622641509434, 0.78, 'x[1] <= 0.752\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0, 0]'),
#  Text(0.9909433962264151, 0.74, 'x[1] <= 0.648\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.9879245283018868, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9939622641509434, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9969811320754717, 0.74, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]')]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - Comentad los resultados.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Se obtienen unas exactitudes de 1 y 0.75 en los grupos de entrenamiento y test respectivamente. La diferencia entre los conjuntos es elevada y se aprecia que el arbol tiene demasiadas reglas, no es apreciable la jerarquia.
#
# </div>

# %% [markdown]
# #### Evitando el *overfitting*
#
# El proceso de construcción de árboles descrito tiende a reducir rápidamente el error de entrenamiento, por lo que generalmente el modelo se ajusta muy bien a las observaciones utilizadas como entrenamiento (conjunto de *train*). Como consecuencia, los árboles de decisión tienden al *overfitting*.
#
# Para prevenirlo, utilizaremos dos hiperparámetros:
#
#    - `max_depth`: la profundidad máxima del árbol. Exploraremos los valores entre 4 y 10.
#    - `min_samples_split`: el número mínimo de observaciones que debe tener una hoja del árbol para poder dividir. Exploraremos los valores: 2, 10, 20, 50 y 100.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Implementación:</strong>
#
# Calculad el valor óptimo de los hiperparámetros `max_depth` y `min_samples_split`. Utilizad una búsqueda de rejilla con validación cruzada para encontrar los valores óptimos. Para cada combinación de valores, calcular su promedio y la desviación estándar. Haced un _heatmap_ para visualizar la precisión según los diferentes valores de los hiperparámetros.
#
# Pódeis utilizar el módulo `GridSearchCV` de `sklearn` el cálculo de los mejores hiperparámetros con el clasificador `DecisionTreeClassifier` (de `tree` de `sklearn`), y `heatmap` de `Seaborn`.
# </div>

# %%
min_samples_split = [2,10,20,50,100]
max_depth = [4,10]
param_grid = {"min_samples_split":min_samples_split,"max_depth":max_depth}
grid = GridSearchCV(clf, param_grid)
grid_search = grid.fit(X_train, y_train)
params = grid_search.cv_results_['params']
means = grid_search.cv_results_["mean_test_score"]
print(grid_search.best_params_)
# Out:
# {'max_depth': 10, 'min_samples_split': 2}

# %%
params
# Out:
# [{'max_depth': 4, 'min_samples_split': 2},
#  {'max_depth': 4, 'min_samples_split': 10},
#  {'max_depth': 4, 'min_samples_split': 20},
#  {'max_depth': 4, 'min_samples_split': 50},
#  {'max_depth': 4, 'min_samples_split': 100},
#  {'max_depth': 10, 'min_samples_split': 2},
#  {'max_depth': 10, 'min_samples_split': 10},
#  {'max_depth': 10, 'min_samples_split': 20},
#  {'max_depth': 10, 'min_samples_split': 50},
#  {'max_depth': 10, 'min_samples_split': 100}]

# %%
for i in range(1, len(grid_search.cv_results_['params']) + 1):
    print("* Combinación de parámetros: {},\n \t**Precisión media: {}, Desviación Estándar: {}".format(
        grid_search.cv_results_['params'][i - 1],
        round(grid_search.cv_results_['mean_test_score'][i - 1], 4),
        round(grid_search.cv_results_['std_test_score'][i - 1], 4)))
# Out:
# * Combinación de parámetros: {'max_depth': 4, 'min_samples_split': 2},
#  	**Precisión media: 0.4694, Desviación Estándar: 0.0343
# * Combinación de parámetros: {'max_depth': 4, 'min_samples_split': 10},
#  	**Precisión media: 0.4694, Desviación Estándar: 0.0343
# * Combinación de parámetros: {'max_depth': 4, 'min_samples_split': 20},
#  	**Precisión media: 0.4675, Desviación Estándar: 0.0353
# * Combinación de parámetros: {'max_depth': 4, 'min_samples_split': 50},
#  	**Precisión media: 0.4606, Desviación Estándar: 0.0318
# * Combinación de parámetros: {'max_depth': 4, 'min_samples_split': 100},
#  	**Precisión media: 0.4256, Desviación Estándar: 0.0198
# * Combinación de parámetros: {'max_depth': 10, 'min_samples_split': 2},
#  	**Precisión media: 0.7444, Desviación Estándar: 0.0309
# * Combinación de parámetros: {'max_depth': 10, 'min_samples_split': 10},
#  	**Precisión media: 0.7388, Desviación Estándar: 0.0284
# * Combinación de parámetros: {'max_depth': 10, 'min_samples_split': 20},
#  	**Precisión media: 0.73, Desviación Estándar: 0.0278
# * Combinación de parámetros: {'max_depth': 10, 'min_samples_split': 50},
#  	**Precisión media: 0.6925, Desviación Estándar: 0.0243
# * Combinación de parámetros: {'max_depth': 10, 'min_samples_split': 100},
#  	**Precisión media: 0.6231, Desviación Estándar: 0.0247

# %%
param1 = [x["max_depth"] for x in params]
param2 = [x["min_samples_split"] for x in params]

precisions = pd.DataFrame(zip(param1, param2, means), columns=['max_depth', 'min_samples_split', 'means'])
precisions = precisions.pivot('max_depth', 'min_samples_split', 'means')
sns.heatmap(precisions,cmap="Blues",annot = True).set(title="Means Heatmap")
# Out:
# [Text(0.5, 1.0, 'Means Heatmap')]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Con el dataset de _train_, entrenad un árbol de desición con la mejor combinación de parámetros encontrada.
#
# - Calculad el _accuracy_ del modelo obtenido sobre _train_ y _test_.
#
# - Calculad la matriz de confusión sobre _test_.
#
# - Representad gráficamente la frontera de decisión con el de _test_.
#
# - Representad el árbol.
#
# </div>

# %%
forest_opt = DecisionTreeClassifier(max_depth=10, min_samples_split=2)
forest_opt.fit(X_train, y_train)
print("Exactitud:", forest_opt.score(X_test, y_test))
# Out:
# Exactitud: 0.7675

# %%
matriz_confusion(forest_opt.fit(X_train,y_train), X_test, y_test)

# %%
plot_decision_boundary(forest_opt.fit(X_train, y_train), X_test, y_test)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
tree.plot_tree(forest_opt)
# Out:
# [Text(0.3771121002906977, 0.9545454545454546, 'x[0] <= -0.905\ngini = 0.75\nsamples = 1600\nvalue = [400, 400, 400, 400]'),
#  Text(0.1334484011627907, 0.8636363636363636, 'x[0] <= -1.872\ngini = 0.642\nsamples = 278\nvalue = [83, 2, 64, 129]'),
#  Text(0.05450581395348837, 0.7727272727272727, 'x[1] <= 1.485\ngini = 0.506\nsamples = 120\nvalue = [3, 0, 47, 70]'),
#  Text(0.027616279069767442, 0.6818181818181818, 'x[0] <= -2.789\ngini = 0.353\nsamples = 83\nvalue = [3, 0, 15, 65]'),
#  Text(0.011627906976744186, 0.5909090909090909, 'x[1] <= 0.229\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 12, 2]'),
#  Text(0.005813953488372093, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.01744186046511628, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0]'),
#  Text(0.0436046511627907, 0.5909090909090909, 'x[0] <= -2.466\ngini = 0.163\nsamples = 69\nvalue = [3, 0, 3, 63]'),
#  Text(0.029069767441860465, 0.5, 'x[0] <= -2.584\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 3, 11]'),
#  Text(0.01744186046511628, 0.4090909090909091, 'x[0] <= -2.759\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10]'),
#  Text(0.011627906976744186, 0.3181818181818182, 'x[0] <= -2.771\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.005813953488372093, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.01744186046511628, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.023255813953488372, 0.3181818181818182, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
#  Text(0.040697674418604654, 0.4090909090909091, 'x[1] <= 0.987\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.03488372093023256, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.046511627906976744, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.05813953488372093, 0.5, 'x[0] <= -1.935\ngini = 0.103\nsamples = 55\nvalue = [3, 0, 0, 52]'),
#  Text(0.05232558139534884, 0.4090909090909091, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38]'),
#  Text(0.06395348837209303, 0.4090909090909091, 'x[0] <= -1.933\ngini = 0.291\nsamples = 17\nvalue = [3, 0, 0, 14]'),
#  Text(0.05813953488372093, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.06976744186046512, 0.3181818181818182, 'x[1] <= -0.421\ngini = 0.219\nsamples = 16\nvalue = [2, 0, 0, 14]'),
#  Text(0.06395348837209303, 0.22727272727272727, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
#  Text(0.0755813953488372, 0.22727272727272727, 'x[1] <= -0.329\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 0, 6]'),
#  Text(0.06976744186046512, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.08139534883720931, 0.13636363636363635, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.08139534883720931, 0.6818181818181818, 'x[0] <= -2.392\ngini = 0.234\nsamples = 37\nvalue = [0, 0, 32, 5]'),
#  Text(0.0755813953488372, 0.5909090909090909, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0]'),
#  Text(0.0872093023255814, 0.5909090909090909, 'x[1] <= 2.101\ngini = 0.401\nsamples = 18\nvalue = [0, 0, 13, 5]'),
#  Text(0.08139534883720931, 0.5, 'x[1] <= 1.869\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5]'),
#  Text(0.0755813953488372, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.0872093023255814, 0.4090909090909091, 'x[1] <= 1.936\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.08139534883720931, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.09302325581395349, 0.3181818181818182, 'x[0] <= -2.207\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.0872093023255814, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.09883720930232558, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.09302325581395349, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]'),
#  Text(0.21239098837209303, 0.7727272727272727, 'x[1] <= 1.582\ngini = 0.592\nsamples = 158\nvalue = [80, 2, 17, 59]'),
#  Text(0.1457122093023256, 0.6818181818181818, 'x[1] <= -1.873\ngini = 0.422\nsamples = 110\nvalue = [78, 2, 0, 30]'),
#  Text(0.11046511627906977, 0.5909090909090909, 'x[1] <= -2.065\ngini = 0.172\nsamples = 21\nvalue = [2, 0, 0, 19]'),
#  Text(0.10465116279069768, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16]'),
#  Text(0.11627906976744186, 0.5, 'x[0] <= -1.14\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.11046511627906977, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.12209302325581395, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.18095930232558138, 0.5909090909090909, 'x[0] <= -1.598\ngini = 0.255\nsamples = 89\nvalue = [76, 2, 0, 11]'),
#  Text(0.14534883720930233, 0.5, 'x[1] <= 0.852\ngini = 0.476\nsamples = 23\nvalue = [14, 0, 0, 9]'),
#  Text(0.13372093023255813, 0.4090909090909091, 'x[1] <= -0.968\ngini = 0.375\nsamples = 16\nvalue = [12, 0, 0, 4]'),
#  Text(0.12790697674418605, 0.3181818181818182, 'x[0] <= -1.743\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 0, 4]'),
#  Text(0.12209302325581395, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.13372093023255813, 0.22727272727272727, 'x[0] <= -1.648\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2]'),
#  Text(0.12790697674418605, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.13953488372093023, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.13953488372093023, 0.3181818181818182, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]'),
#  Text(0.1569767441860465, 0.4090909090909091, 'x[0] <= -1.697\ngini = 0.408\nsamples = 7\nvalue = [2, 0, 0, 5]'),
#  Text(0.1511627906976744, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.16279069767441862, 0.3181818181818182, 'x[0] <= -1.635\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.1569767441860465, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.1686046511627907, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.21656976744186046, 0.5, 'x[0] <= -0.929\ngini = 0.116\nsamples = 66\nvalue = [62, 2, 0, 2]'),
#  Text(0.2005813953488372, 0.4090909090909091, 'x[1] <= -1.735\ngini = 0.09\nsamples = 64\nvalue = [61, 1, 0, 2]'),
#  Text(0.18604651162790697, 0.3181818181818182, 'x[1] <= -1.767\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.18023255813953487, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.19186046511627908, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.21511627906976744, 0.3181818181818182, 'x[1] <= 1.436\ngini = 0.064\nsamples = 61\nvalue = [59, 1, 0, 1]'),
#  Text(0.20348837209302326, 0.22727272727272727, 'x[0] <= -1.076\ngini = 0.034\nsamples = 58\nvalue = [57, 1, 0, 0]'),
#  Text(0.19767441860465115, 0.13636363636363635, 'gini = 0.0\nsamples = 49\nvalue = [49, 0, 0, 0]'),
#  Text(0.20930232558139536, 0.13636363636363635, 'x[0] <= -1.072\ngini = 0.198\nsamples = 9\nvalue = [8, 1, 0, 0]'),
#  Text(0.20348837209302326, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.21511627906976744, 0.045454545454545456, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]'),
#  Text(0.22674418604651161, 0.22727272727272727, 'x[1] <= 1.477\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.22093023255813954, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.23255813953488372, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.23255813953488372, 0.4090909090909091, 'x[0] <= -0.917\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.22674418604651161, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.23837209302325582, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.27906976744186046, 0.6818181818181818, 'x[1] <= 2.639\ngini = 0.508\nsamples = 48\nvalue = [2, 0, 17, 29]'),
#  Text(0.27325581395348836, 0.5909090909090909, 'x[0] <= -0.948\ngini = 0.22\nsamples = 33\nvalue = [2, 0, 2, 29]'),
#  Text(0.26744186046511625, 0.5, 'x[1] <= 2.502\ngini = 0.174\nsamples = 32\nvalue = [1, 0, 2, 29]'),
#  Text(0.2558139534883721, 0.4090909090909091, 'x[1] <= 1.66\ngini = 0.069\nsamples = 28\nvalue = [1, 0, 0, 27]'),
#  Text(0.25, 0.3181818181818182, 'x[1] <= 1.639\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]'),
#  Text(0.2441860465116279, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.2558139534883721, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.2616279069767442, 0.3181818181818182, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 0, 25]'),
#  Text(0.27906976744186046, 0.4090909090909091, 'x[0] <= -1.258\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.27325581395348836, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.28488372093023256, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.27906976744186046, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.28488372093023256, 0.5909090909090909, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0]'),
#  Text(0.6207757994186046, 0.8636363636363636, 'x[1] <= -0.935\ngini = 0.745\nsamples = 1322\nvalue = [317, 398, 336, 271]'),
#  Text(0.37318313953488375, 0.7727272727272727, 'x[1] <= -1.774\ngini = 0.608\nsamples = 228\nvalue = [109, 87, 2, 30]'),
#  Text(0.30523255813953487, 0.6818181818181818, 'x[1] <= -2.827\ngini = 0.465\nsamples = 98\nvalue = [65, 3, 0, 30]'),
#  Text(0.29941860465116277, 0.5909090909090909, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24]'),
#  Text(0.311046511627907, 0.5909090909090909, 'x[0] <= -0.458\ngini = 0.22\nsamples = 74\nvalue = [65, 3, 0, 6]'),
#  Text(0.29651162790697677, 0.5, 'x[1] <= -2.256\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.29069767441860467, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.3023255813953488, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.32558139534883723, 0.5, 'x[1] <= -2.634\ngini = 0.163\nsamples = 69\nvalue = [63, 3, 0, 3]'),
#  Text(0.313953488372093, 0.4090909090909091, 'x[0] <= 0.507\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 0, 3]'),
#  Text(0.3081395348837209, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.31976744186046513, 0.3181818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]'),
#  Text(0.3372093023255814, 0.4090909090909091, 'x[1] <= -1.867\ngini = 0.094\nsamples = 61\nvalue = [58, 3, 0, 0]'),
#  Text(0.3313953488372093, 0.3181818181818182, 'gini = 0.0\nsamples = 49\nvalue = [49, 0, 0, 0]'),
#  Text(0.3430232558139535, 0.3181818181818182, 'x[1] <= -1.864\ngini = 0.375\nsamples = 12\nvalue = [9, 3, 0, 0]'),
#  Text(0.3372093023255814, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.3488372093023256, 0.22727272727272727, 'x[0] <= 0.669\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0, 0]'),
#  Text(0.3430232558139535, 0.13636363636363635, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.3546511627906977, 0.13636363636363635, 'x[0] <= 1.89\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0]'),
#  Text(0.3488372093023256, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.36046511627906974, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.44113372093023256, 0.6818181818181818, 'x[0] <= 2.794\ngini = 0.468\nsamples = 130\nvalue = [44, 84, 2, 0]'),
#  Text(0.4171511627906977, 0.5909090909090909, 'x[0] <= -0.297\ngini = 0.32\nsamples = 103\nvalue = [18, 83, 2, 0]'),
#  Text(0.39244186046511625, 0.5, 'x[1] <= -1.021\ngini = 0.375\nsamples = 16\nvalue = [12, 4, 0, 0]'),
#  Text(0.37790697674418605, 0.4090909090909091, 'x[0] <= -0.383\ngini = 0.26\nsamples = 13\nvalue = [11, 2, 0, 0]'),
#  Text(0.36627906976744184, 0.3181818181818182, 'x[1] <= -1.311\ngini = 0.165\nsamples = 11\nvalue = [10, 1, 0, 0]'),
#  Text(0.36046511627906974, 0.22727272727272727, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]'),
#  Text(0.37209302325581395, 0.22727272727272727, 'x[0] <= -0.596\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.36627906976744184, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.37790697674418605, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.38953488372093026, 0.3181818181818182, 'x[0] <= -0.358\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.38372093023255816, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.3953488372093023, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4069767441860465, 0.4090909090909091, 'x[1] <= -0.941\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]'),
#  Text(0.4011627906976744, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.4127906976744186, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4418604651162791, 0.5, 'x[1] <= -1.523\ngini = 0.17\nsamples = 87\nvalue = [6, 79, 2, 0]'),
#  Text(0.43023255813953487, 0.4090909090909091, 'x[0] <= 0.134\ngini = 0.346\nsamples = 27\nvalue = [6, 21, 0, 0]'),
#  Text(0.42441860465116277, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.436046511627907, 0.3181818181818182, 'x[0] <= 2.424\ngini = 0.219\nsamples = 24\nvalue = [3, 21, 0, 0]'),
#  Text(0.43023255813953487, 0.22727272727272727, 'gini = 0.0\nsamples = 20\nvalue = [0, 20, 0, 0]'),
#  Text(0.4418604651162791, 0.22727272727272727, 'x[1] <= -1.658\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0]'),
#  Text(0.436046511627907, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.4476744186046512, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.45348837209302323, 0.4090909090909091, 'x[1] <= -1.064\ngini = 0.064\nsamples = 60\nvalue = [0, 58, 2, 0]'),
#  Text(0.4476744186046512, 0.3181818181818182, 'gini = 0.0\nsamples = 46\nvalue = [0, 46, 0, 0]'),
#  Text(0.45930232558139533, 0.3181818181818182, 'x[1] <= -1.058\ngini = 0.245\nsamples = 14\nvalue = [0, 12, 2, 0]'),
#  Text(0.45348837209302323, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.46511627906976744, 0.22727272727272727, 'x[1] <= -0.992\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1, 0]'),
#  Text(0.45930232558139533, 0.13636363636363635, 'x[1] <= -1.006\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0]'),
#  Text(0.45348837209302323, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.46511627906976744, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.47093023255813954, 0.13636363636363635, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.46511627906976744, 0.5909090909090909, 'x[1] <= -1.022\ngini = 0.071\nsamples = 27\nvalue = [26, 1, 0, 0]'),
#  Text(0.45930232558139533, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [25, 0, 0, 0]'),
#  Text(0.47093023255813954, 0.5, 'x[0] <= 3.572\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.46511627906976744, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.47674418604651164, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8683684593023255, 0.7727272727272727, 'x[0] <= 2.861\ngini = 0.741\nsamples = 1094\nvalue = [208, 311, 334, 241]'),
#  Text(0.7687136627906976, 0.6818181818181818, 'x[0] <= 1.734\ngini = 0.738\nsamples = 1002\nvalue = [178, 249, 334, 241]'),
#  Text(0.6551598837209303, 0.5909090909090909, 'x[1] <= 0.223\ngini = 0.748\nsamples = 841\nvalue = [178, 209, 227, 227]'),
#  Text(0.5559593023255814, 0.5, 'x[0] <= -0.042\ngini = 0.613\nsamples = 232\nvalue = [11, 50, 128, 43]'),
#  Text(0.5203488372093024, 0.4090909090909091, 'x[1] <= 0.058\ngini = 0.322\nsamples = 52\nvalue = [2, 42, 8, 0]'),
#  Text(0.5, 0.3181818181818182, 'x[0] <= -0.782\ngini = 0.189\nsamples = 39\nvalue = [2, 35, 2, 0]'),
#  Text(0.4883720930232558, 0.22727272727272727, 'x[1] <= -0.28\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]'),
#  Text(0.48255813953488375, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.4941860465116279, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.5116279069767442, 0.22727272727272727, 'x[1] <= -0.24\ngini = 0.108\nsamples = 35\nvalue = [0, 33, 2, 0]'),
#  Text(0.5058139534883721, 0.13636363636363635, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0, 0]'),
#  Text(0.5174418604651163, 0.13636363636363635, 'x[1] <= -0.183\ngini = 0.32\nsamples = 10\nvalue = [0, 8, 2, 0]'),
#  Text(0.5116279069767442, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5232558139534884, 0.045454545454545456, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.5406976744186046, 0.3181818181818182, 'x[0] <= -0.28\ngini = 0.497\nsamples = 13\nvalue = [0, 7, 6, 0]'),
#  Text(0.5348837209302325, 0.22727272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]'),
#  Text(0.5465116279069767, 0.22727272727272727, 'x[0] <= -0.226\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0]'),
#  Text(0.5406976744186046, 0.13636363636363635, 'x[0] <= -0.277\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.5348837209302325, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5465116279069767, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5523255813953488, 0.13636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.5915697674418605, 0.4090909090909091, 'x[1] <= -0.311\ngini = 0.494\nsamples = 180\nvalue = [9, 8, 120, 43]'),
#  Text(0.5755813953488372, 0.3181818181818182, 'x[0] <= 0.246\ngini = 0.14\nsamples = 66\nvalue = [0, 5, 61, 0]'),
#  Text(0.5697674418604651, 0.22727272727272727, 'x[0] <= 0.172\ngini = 0.5\nsamples = 10\nvalue = [0, 5, 5, 0]'),
#  Text(0.563953488372093, 0.13636363636363635, 'x[1] <= -0.534\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5, 0]'),
#  Text(0.5581395348837209, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.5697674418604651, 0.045454545454545456, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]'),
#  Text(0.5755813953488372, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.5813953488372093, 0.22727272727272727, 'gini = 0.0\nsamples = 56\nvalue = [0, 0, 56, 0]'),
#  Text(0.6075581395348837, 0.3181818181818182, 'x[0] <= 0.28\ngini = 0.583\nsamples = 114\nvalue = [9, 3, 59, 43]'),
#  Text(0.5930232558139535, 0.22727272727272727, 'x[0] <= 0.119\ngini = 0.263\nsamples = 27\nvalue = [0, 2, 23, 2]'),
#  Text(0.5872093023255814, 0.13636363636363635, 'x[0] <= 0.113\ngini = 0.473\nsamples = 13\nvalue = [0, 2, 9, 2]'),
#  Text(0.5813953488372093, 0.045454545454545456, 'gini = 0.403\nsamples = 12\nvalue = [0, 2, 9, 1]'),
#  Text(0.5930232558139535, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5988372093023255, 0.13636363636363635, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]'),
#  Text(0.622093023255814, 0.22727272727272727, 'x[1] <= 0.085\ngini = 0.596\nsamples = 87\nvalue = [9, 1, 36, 41]'),
#  Text(0.6104651162790697, 0.13636363636363635, 'x[0] <= 1.287\ngini = 0.499\nsamples = 55\nvalue = [0, 0, 26, 29]'),
#  Text(0.6046511627906976, 0.045454545454545456, 'gini = 0.48\nsamples = 45\nvalue = [0, 0, 18, 27]'),
#  Text(0.6162790697674418, 0.045454545454545456, 'gini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2]'),
#  Text(0.6337209302325582, 0.13636363636363635, 'x[0] <= 0.908\ngini = 0.682\nsamples = 32\nvalue = [9, 1, 10, 12]'),
#  Text(0.627906976744186, 0.045454545454545456, 'gini = 0.685\nsamples = 21\nvalue = [7, 1, 8, 5]'),
#  Text(0.6395348837209303, 0.045454545454545456, 'gini = 0.529\nsamples = 11\nvalue = [2, 0, 2, 7]'),
#  Text(0.7543604651162791, 0.5, 'x[1] <= 2.896\ngini = 0.739\nsamples = 609\nvalue = [167, 159, 99, 184]'),
#  Text(0.7122093023255814, 0.4090909090909091, 'x[0] <= 0.899\ngini = 0.715\nsamples = 533\nvalue = [167, 128, 54, 184]'),
#  Text(0.6831395348837209, 0.3181818181818182, 'x[1] <= 2.042\ngini = 0.712\nsamples = 380\nvalue = [133, 126, 41, 80]'),
#  Text(0.6686046511627907, 0.22727272727272727, 'x[1] <= 1.045\ngini = 0.678\nsamples = 337\nvalue = [133, 126, 40, 38]'),
#  Text(0.6569767441860465, 0.13636363636363635, 'x[0] <= 0.029\ngini = 0.665\nsamples = 222\nvalue = [41, 111, 40, 30]'),
#  Text(0.6511627906976745, 0.045454545454545456, 'gini = 0.305\nsamples = 74\nvalue = [6, 61, 7, 0]'),
#  Text(0.6627906976744186, 0.045454545454545456, 'gini = 0.739\nsamples = 148\nvalue = [35, 50, 33, 30]'),
#  Text(0.6802325581395349, 0.13636363636363635, 'x[1] <= 1.272\ngini = 0.338\nsamples = 115\nvalue = [92, 15, 0, 8]'),
#  Text(0.6744186046511628, 0.045454545454545456, 'gini = 0.454\nsamples = 43\nvalue = [28, 15, 0, 0]'),
#  Text(0.686046511627907, 0.045454545454545456, 'gini = 0.198\nsamples = 72\nvalue = [64, 0, 0, 8]'),
#  Text(0.6976744186046512, 0.22727272727272727, 'x[0] <= 0.763\ngini = 0.045\nsamples = 43\nvalue = [0, 0, 1, 42]'),
#  Text(0.6918604651162791, 0.13636363636363635, 'gini = 0.0\nsamples = 42\nvalue = [0, 0, 0, 42]'),
#  Text(0.7034883720930233, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.7412790697674418, 0.3181818181818182, 'x[1] <= 2.506\ngini = 0.481\nsamples = 153\nvalue = [34, 2, 13, 104]'),
#  Text(0.7267441860465116, 0.22727272727272727, 'x[0] <= 1.303\ngini = 0.41\nsamples = 140\nvalue = [34, 2, 2, 102]'),
#  Text(0.7151162790697675, 0.13636363636363635, 'x[1] <= 1.668\ngini = 0.495\nsamples = 91\nvalue = [34, 2, 0, 55]'),
#  Text(0.7093023255813954, 0.045454545454545456, 'gini = 0.527\nsamples = 70\nvalue = [33, 2, 0, 35]'),
#  Text(0.7209302325581395, 0.045454545454545456, 'gini = 0.091\nsamples = 21\nvalue = [1, 0, 0, 20]'),
#  Text(0.7383720930232558, 0.13636363636363635, 'x[0] <= 1.727\ngini = 0.078\nsamples = 49\nvalue = [0, 0, 2, 47]'),
#  Text(0.7325581395348837, 0.045454545454545456, 'gini = 0.042\nsamples = 47\nvalue = [0, 0, 1, 46]'),
#  Text(0.7441860465116279, 0.045454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.7558139534883721, 0.22727272727272727, 'x[0] <= 1.085\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2]'),
#  Text(0.75, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.7616279069767442, 0.13636363636363635, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]'),
#  Text(0.7965116279069767, 0.4090909090909091, 'x[1] <= 3.879\ngini = 0.483\nsamples = 76\nvalue = [0, 31, 45, 0]'),
#  Text(0.7906976744186046, 0.3181818181818182, 'x[0] <= 1.137\ngini = 0.298\nsamples = 55\nvalue = [0, 10, 45, 0]'),
#  Text(0.7790697674418605, 0.22727272727272727, 'x[1] <= 3.783\ngini = 0.05\nsamples = 39\nvalue = [0, 1, 38, 0]'),
#  Text(0.7732558139534884, 0.13636363636363635, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35, 0]'),
#  Text(0.7848837209302325, 0.13636363636363635, 'x[0] <= 0.262\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]'),
#  Text(0.7790697674418605, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.7906976744186046, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.8023255813953488, 0.22727272727272727, 'x[1] <= 3.228\ngini = 0.492\nsamples = 16\nvalue = [0, 9, 7, 0]'),
#  Text(0.7965116279069767, 0.13636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.8081395348837209, 0.13636363636363635, 'x[1] <= 3.665\ngini = 0.375\nsamples = 12\nvalue = [0, 9, 3, 0]'),
#  Text(0.8023255813953488, 0.045454545454545456, 'gini = 0.49\nsamples = 7\nvalue = [0, 4, 3, 0]'),
#  Text(0.813953488372093, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.8023255813953488, 0.3181818181818182, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0]'),
#  Text(0.8822674418604651, 0.5909090909090909, 'x[1] <= 3.029\ngini = 0.489\nsamples = 161\nvalue = [0, 40, 107, 14]'),
#  Text(0.8459302325581395, 0.5, 'x[1] <= -0.522\ngini = 0.421\nsamples = 144\nvalue = [0, 24, 106, 14]'),
#  Text(0.8197674418604651, 0.4090909090909091, 'x[1] <= -0.613\ngini = 0.231\nsamples = 15\nvalue = [0, 13, 2, 0]'),
#  Text(0.813953488372093, 0.3181818181818182, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]'),
#  Text(0.8255813953488372, 0.3181818181818182, 'x[0] <= 2.351\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2, 0]'),
#  Text(0.8197674418604651, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.8313953488372093, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.872093023255814, 0.4090909090909091, 'x[0] <= 2.033\ngini = 0.331\nsamples = 129\nvalue = [0, 11, 104, 14]'),
#  Text(0.8488372093023255, 0.3181818181818182, 'x[1] <= 1.787\ngini = 0.46\nsamples = 39\nvalue = [0, 0, 25, 14]'),
#  Text(0.8430232558139535, 0.22727272727272727, 'x[1] <= 0.574\ngini = 0.493\nsamples = 25\nvalue = [0, 0, 11, 14]'),
#  Text(0.8313953488372093, 0.13636363636363635, 'x[1] <= 0.207\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3]'),
#  Text(0.8255813953488372, 0.045454545454545456, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.8372093023255814, 0.045454545454545456, 'gini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3]'),
#  Text(0.8546511627906976, 0.13636363636363635, 'x[0] <= 1.983\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11]'),
#  Text(0.8488372093023255, 0.045454545454545456, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9]'),
#  Text(0.8604651162790697, 0.045454545454545456, 'gini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.8546511627906976, 0.22727272727272727, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]'),
#  Text(0.8953488372093024, 0.3181818181818182, 'x[1] <= 2.662\ngini = 0.215\nsamples = 90\nvalue = [0, 11, 79, 0]'),
#  Text(0.8895348837209303, 0.22727272727272727, 'x[0] <= 2.812\ngini = 0.15\nsamples = 86\nvalue = [0, 7, 79, 0]'),
#  Text(0.877906976744186, 0.13636363636363635, 'x[1] <= -0.248\ngini = 0.096\nsamples = 79\nvalue = [0, 4, 75, 0]'),
#  Text(0.872093023255814, 0.045454545454545456, 'gini = 0.469\nsamples = 8\nvalue = [0, 3, 5, 0]'),
#  Text(0.8837209302325582, 0.045454545454545456, 'gini = 0.028\nsamples = 71\nvalue = [0, 1, 70, 0]'),
#  Text(0.9011627906976745, 0.13636363636363635, 'x[1] <= 1.515\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4, 0]'),
#  Text(0.8953488372093024, 0.045454545454545456, 'gini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]'),
#  Text(0.9069767441860465, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.9011627906976745, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.9186046511627907, 0.5, 'x[1] <= 3.228\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1, 0]'),
#  Text(0.9127906976744186, 0.4090909090909091, 'x[0] <= 1.994\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0]'),
#  Text(0.9069767441860465, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9186046511627907, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.9244186046511628, 0.4090909090909091, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0, 0]'),
#  Text(0.9680232558139535, 0.6818181818181818, 'x[0] <= 3.741\ngini = 0.44\nsamples = 92\nvalue = [30, 62, 0, 0]'),
#  Text(0.9534883720930233, 0.5909090909090909, 'x[1] <= -0.309\ngini = 0.172\nsamples = 63\nvalue = [6, 57, 0, 0]'),
#  Text(0.9418604651162791, 0.5, 'x[0] <= 3.364\ngini = 0.494\nsamples = 9\nvalue = [5, 4, 0, 0]'),
#  Text(0.936046511627907, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.9476744186046512, 0.4090909090909091, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]'),
#  Text(0.9651162790697675, 0.5, 'x[1] <= 0.014\ngini = 0.036\nsamples = 54\nvalue = [1, 53, 0, 0]'),
#  Text(0.9593023255813954, 0.4090909090909091, 'x[1] <= -0.055\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0, 0]'),
#  Text(0.9534883720930233, 0.3181818181818182, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]'),
#  Text(0.9651162790697675, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9709302325581395, 0.4090909090909091, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0, 0]'),
#  Text(0.9825581395348837, 0.5909090909090909, 'x[1] <= 0.599\ngini = 0.285\nsamples = 29\nvalue = [24, 5, 0, 0]'),
#  Text(0.9767441860465116, 0.5, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]'),
#  Text(0.9883720930232558, 0.5, 'x[1] <= 0.752\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0, 0]'),
#  Text(0.9825581395348837, 0.4090909090909091, 'x[0] <= 3.867\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.9767441860465116, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9883720930232558, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9941860465116279, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]')]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - Comentar los resultados de la búsqueda de los mejores hiperparámetros.
#    - ¿Cómo son las fronteras de decisión? ¿Tiene sentido que tengan esta forma con el algoritmo utilizado?
#    - ¿Cómo son las predicciones obtenidas sobre el conjunto de test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Se consiguen los mejores hiperparametros para "max_depth = 10" y "min_samples_split = 2" con esos hiperparametros se consigue una exactitud de 0.7675, mejorando por tanto un poco el anteror modelo.
# Las fronteras de decision tiene forma rectanguar formando una especie de espiral, lo cual tiene sentido ya que cada nodo interno representa una prueba en una caracteristica por lo que no es posible tener formas redondeadas o curvilineas.
#
# </div>

# %% [markdown]
# <a id='ej2'></a>
# # 2. Implementación del caso práctico (5 puntos)
#
# Como experto en análisis de datos, sabemos la importancia de que las empresas de tarjetas de crédito puedan identificar y prevenir transacciones fraudulentas para proteger a sus clientes. En este sentido, estudiaremos un conjunto de datos que contiene información sobre transacciones realizadas con tarjetas de crédito en septiembre de 2013 por titulares de tarjetas europeos.
#
# Este conjunto de datos presenta transacciones ocurridas en dos días, donde se registraron 492 casos de fraude de un total de 284,807 transacciones. Es importante destacar que todas las variables de entrada son numéricas y fueron obtenidas a través de una transformación PCA. Lamentablemente, debido a razones de confidencialidad, no se pueden proporcionar las características originales ni más información sobre los datos. Las variables V1 a V28 representan los componentes principales obtenidos con PCA, mientras que "Time" e "Amount" son las únicas variables que no han sido transformadas con PCA. La variable "Time" indica los segundos transcurridos entre cada transacción y la primera transacción del conjunto de datos, mientras que "Amount" representa el monto de la transacción. La variable "Class" es la variable de respuesta y toma el valor 1 en caso de fraude y 0 en caso contrario.
#
# Fuente: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %% [markdown]
# ## 2.0. Carga de datos
#
# Lo primero que haremos será cargar el conjunto de datos, visualizar las primeras filas, y verificar:
#
# - La cantidad total de filas y columnas en el DataFrame.
# - El nombre de cada columna del DataFrame.
# - El número de valores no nulos en cada columna.
# - El tipo de datos de cada columna, que puede ser int, float, object, entre otros.
# - La cantidad de memoria utilizada por el DataFrame.

# %%
import numpy as np 
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')

# %%
# Número de filas y columnas
print("Número de columnas:", len(data.columns))
print("Número de filas:",len(data.index))
# Out:
# Número de columnas: 31
# Número de filas: 284807

# %%
# Nombre de cada columnas.
column_names = data.columns.values.tolist()
column_names
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount',
#  'Class']

# %%
# valores no nulos y tipo de dato de cada columna
data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Memoria usada por el datset
import sys
print("Memoria usada por del dataset:",sys.getsizeof(data),"bytes")
# Out:
# Memoria usada por del dataset: 70632280 bytes

# %% [markdown]
# ## 2.1. Preprocesado de datos y análisis exploratorio
#
# El preprocesado y análisis exploratorio de los datos es un paso crítico y fundamental en cualquier proyecto de análisis de datos o de aprendizaje automático. Ayuda a los investigadores a comprender mejor los datos, descubrir patrones y relaciones, identificar problemas y seleccionar las técnicas de análisis adecuadas para el conjunto de datos

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# Calculad las frecuencias de la variable _target_ (`Class`) y haced un gráfico de barras.

# %%
# Frecuencias de "Class"
frecuency = data.groupby("Class").agg(Frecuency=("Class","count")).reset_index()
frecuency
# Out:
#    Class  Frecuency
# 0      0     284315
# 1      1        492

# %%
type(frecuency["Class"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
fig, ax = plt.subplots()
ax.bar(x = frecuency["Class"], height = frecuency["Frecuency"],log=True,alpha = 0.5)
plt.title("Frecuencia de la variable Class")
plt.ylabel("Frecuencia en escala logarítmica")
plt.xticks(frecuency["Class"])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# Analizar la distribución de las variables descriptoras. Representa gráficamente el histograma de las 30 variables separándo las observaciones según la clase a la que pertenece. Organiza todos los histogramas en 10 filas y 3 columnas.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
fig = plt.figure(figsize=(17, 45))
#fig.tight_layout()
# Separamos por clases:
data_0 = data.loc[data['Class'] == 0]
data_1 = data.loc[data['Class'] == 1]

# Ciclo, le restamos "1" para que no grafique "Class", lo que haremos será superponer 2 histogramas:
for i in range(len(data.columns)-1):
    ax = plt.subplot(10,3,i+1)
    ax.hist(data_0.iloc[:,i], color='darkblue', ec = 'black', bins=70, alpha=0.3, label="0", density=True)
    ax.hist(data_1.iloc[:,i], color='orange', ec = 'black', bins=70, alpha=0.3, label="1", density=True)
    
    ax.legend(loc='upper left')
    ax.set_title(data.columns[i])
fig = plt.figure(figsize=(17, 20))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Cómo es la relación de la frecuencias de la variable `Class`?
#    - ¿Qué información nos proporcionan los histogramas?, ¿Existe otra forma de visualización que pudiera ser útil, en este caso?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# La variable "Class" muestra diferencias entre sus dos categorias, como sabemos la categoria 0 tiene muchas mas ocurrencias que la 1 y las formas del histograma difieren entre categorias, haciendose mas notable en unas varibales que en otras.
# Los histogramas nos proporcianan una imagen de la distribucion de las variables.
# Pienso que podria representarse mejor con boxplots.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# Los datos en bruto presentan algunos problemas. En primer lugar, las columnas `Time` y `Amount` son demasiado variables para utilizarlas directamente. Eliminad la columna `Time` (ya que no está claro qué significa) y tomad el logaritmo de la columna `Amount` para reducir su rango.
#
# Para evitar la indeterminación "log(0)", sumádle 1 céntimo de dolar (0.001) a la columna `Amount` antes de calcular el logaritmo. No olvidéis que finalmente tenéis que reemplazar la columna `Amount` por `Log Amount`
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
# Sacamos Time del conjunto de datos:
data_time = data.pop("Time")

# %%
from numpy.ma.core import log

# Sumamos 0.001 a "Amount":
amount = np.array(data["Amount"]+0.001)

# Creamos la nueva variable "Log Amount" y eliminamos "Amount":
data["Log Amount"] = log(amount)


data_amount = data.pop("Amount")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Separad los descriptores de la respuesta. Nombrad los conjuntos como: X, y.
#
# - Dividid el _dataset_ en dos subconjuntos, __*train*__ (80% de los datos) y __*test*__ (20% de los datos). Nombrad los conjuntos como: X_train, X_test, y_train, y_test. Podéis utlizar la función `train_test_split`de la biblioteca `model_selection`de `sklearn`. Utilizad la opción `random_state = 24` y aseguraros que la división sea estratificada, es decir, que se mantenga la misma proporción de clases tanto en el conjunto de entrenamiento como en el de prueba.
#
# Tened en cuenta que la matrices de las clases `y_train` e `y_test` deben estar codificadas. La función `to_categorical` de la librería `TensorFlow` de `Keras` se utiliza para convertir una matriz de etiquetas de clase (enteros) en una matriz de etiquetas de clase codificadas en one-hot.
#
# La codificación one-hot es un proceso mediante el cual las etiquetas categóricas se convierten en vectores binarios, donde cada vector tiene una longitud igual al número de clases. Cada vector tiene un valor de 1 en la posición correspondiente a la clase y un valor de 0 en todas las demás posiciones. Esto se hace para permitir que los modelos de aprendizaje automático comprendan mejor la estructura de las etiquetas categóricas.
# </div>

# %%
# Eliminamos y almacenamos variable objetivo:
y = data.pop("Class")

# Resto descriptores:
X = data

# %%
# Importamos:
import keras
from keras.utils import to_categorical

# Transformamos nuestra variable objetivo en vectores binarios (dos clases):
y = to_categorical(y, num_classes=2, dtype='int32')

# %%
# Observamos su dimensionalidad:
print("Dimensiones descriptores: {}.\n".format(X.shape))

print("Dimensiones respuesta: {}.\n".format(y.shape))
# Out:
# Dimensiones descriptores: (284807, 29).
#
# Dimensiones respuesta: (284807, 2).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                                shuffle=True, random_state = 24, stratify=y)

# %%
# Dimensiones de los distintos conjuntos obtenidos:
print("Dimensiones del conjunto de entrenamiento X: {}.\n".format(X_train.shape))

print("Dimensiones del conjunto de prueba X: {}.\n".format(X_test.shape))

print("Dimensiones del conjunto de entrenamiento Y: {}.\n".format(y_train.shape))

print("Dimensiones del conjunto de prueba Y: {}.\n".format(y_test.shape))
# Out:
# Dimensiones del conjunto de entrenamiento X: (227845, 29).
#
# Dimensiones del conjunto de prueba X: (56962, 29).
#
# Dimensiones del conjunto de entrenamiento Y: (227845, 2).
#
# Dimensiones del conjunto de prueba Y: (56962, 2).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Normalizad los descriptores utilizando `StandardScaler`de `sklearn`.
# - Mostrad las dimensiones del conjunto de descriptores original, del conjunto de entrenamiento y del conjunto de prueba.
#
# <strong>Nota:</strong> Recordad que el `StandardScaler` sólo se ajusta utilizando los descriptores de entrenamiento para evitar fugas de información o "data leakage". La fuga de información se produce cuando se utiliza información de los datos de prueba o validación para ajustar el modelo. En otras palabras, si se ajusta el modelo de escalado con todo el conjunto de datos, se estaría utilizando información de prueba o validación para el ajuste, lo que podría hacer que el modelo parezca más preciso de lo que realmente es.
#
# </div>

# %%
from sklearn.preprocessing import StandardScaler

scl = StandardScaler()

# Normalizamos todas las variables del conjunto de entrenamiento y creamos un dataframe:
X_train = scl.fit_transform(X_train)
X_train = pd.DataFrame(X_train)

# %% [markdown]
# ## 2.2. Entrenamiento, validación y prueba de una red neuronal con los datos originales
#
# Como herramienta de clasificación que nos permita predecir si una transacción es fraudulenta o no, utilizaremos un perceptrón multicapa. Un perceptrón multicapa (MLP, por sus siglas en inglés) es una red neuronal artificial compuesta por múltiples capas de unidades de procesamiento (neuronas), donde cada capa está conectada a la siguiente capa a través de un conjunto de conexiones ponderadas. El MLP es capaz de realizar tanto tareas de clasificación como de regresión al aprender a mapear las entradas a las salidas deseadas a través de una función de activación no lineal. La red utiliza un algoritmo de aprendizaje supervisado que ajusta los pesos de las conexiones durante el entrenamiento para minimizar la diferencia entre las salidas producidas por la red y las salidas deseadas. Debido a su capacidad para modelar relaciones no lineales complejas, el MLP es uno de los modelos más utilizados en el campo del aprendizaje automático.

# %% [markdown]
# Crearemos y entrenaremos una red Perceptrón Multicapa (MLP) con 4 capas ocultas de 20 neuronas cada una y con función de activación `relu`. Usaremos la clase `Sequential` de la libreria `keras`para crear el modelo de forma secuencial, es decir, apilando capas una encima de la otra. `Sequential` es la forma más sencilla de crear modelos de redes neuronales en `keras`, ya que no requiere definir la dirección del grafo computacional como ocurre en otros tipos de modelos más complejos.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Cread el modelo `Sequential`. Agregad las 4 capas ocultas con 20 neuronas cada una utilizando el método `.add()` y función de activación `relu`. Agregad la capa de salida con 2 neuronas de salida (una para la clase 0 y la otra para la clase 1) y función de activación `sigmoid`. Mostrad el resumen de la red creada con el método `.summary()`
# - Compilad el modelo utilizando el método `.compile()`, especificando el optimizador `adam`, la función de pérdida `binary_crossentropy` y las métrica de evaluación `accuracy`.
# - Entrenad el modelo utilizando el método `.fit()` con `X_train`, especificad el número de épocas en 100 y el tamaño del lote en 2048. Validad su rendimiento haciendo validación cruzada con el 80% de los datos para el entrenamiento. Configura el parámetro `validation_split=0.2`.
# - Graficad la pérdida (`loss`) tanto de entrenamiento como de validación en función de las épocas.
# - Graficad la exactitud (`accuracy`) tanto de entrenamiento como de validación en función de las épocas.
#
# <strong>Nota:</strong> Para la presentación del informe, configurad el parámetro `verbose=0`, para evitar mostrar información durante el entreno.
#
# </div>

# %%
from keras import Sequential

# Modelo:
sqt = Sequential()

# Agregamos 4 capas ocultas:
sqt.add(keras.layers.Dense(20, activation='relu', input_shape=[X_train.shape[1]]))
sqt.add(keras.layers.Dense(20, activation='relu'))
sqt.add(keras.layers.Dense(20, activation='relu'))
sqt.add(keras.layers.Dense(20, activation='relu'))

# Indicamos dos neuronas para predecir dos clases:
sqt.add(keras.layers.Dense(2, activation='sigmoid'))
sqt.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
sqt.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 20)                600
#
#  dense_36 (Dense)            (None, 20)                420
#
#  dense_37 (Dense)            (None, 20)                420
#
#  dense_38 (Dense)            (None, 20)                420
#
#  dense_39 (Dense)            (None, 2)                 42
#
# =================================================================
# Total params: 1,902
# Trainable params: 1,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamos el modelo:
f_model = sqt.fit(X_train, y_train, epochs=100, batch_size=2048, validation_split=0.2, verbose=0)

# %%
# Dataframe con la history:
hist = pd.DataFrame(f_model.history)

# Añadimos el número de época:
hist['epoch'] = f_model.epoch
hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy  epoch
# 0  0.302294  0.941172  0.036500      0.998354      0
# 1  0.018651  0.998250  0.009801      0.998354      1
# 2  0.009083  0.998250  0.006399      0.998354      2
# 3  0.006628  0.998250  0.004706      0.998354      3
# 4  0.005322  0.998250  0.003874      0.998354      4

# %%
plt.figure(figsize=(10,10))
# Graficamos el error de entrenamiento y el del conjunto de validación.
plt.xlabel('epoch')
plt.ylabel('Loss vs Iterations')
plt.plot(hist['epoch'], hist['loss'], label = 'Error entrenamiento')
plt.plot(hist['epoch'], hist['val_loss'], label = 'Error validacion')
plt.legend()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %%
plt.figure(figsize=(10,10))
#Graficamos la precisión de entrenamiento y la de validación
plt.xlabel('epoch')
plt.ylabel('Accuracy vs Iterations')
plt.plot(hist['epoch'], hist['accuracy'], label = 'Exactitud de entrenamiento')
plt.plot(hist['epoch'], hist['val_accuracy'], label = 'Exactitud validación')
plt.legend()

# %% [markdown]
# Una vez entrenado y validado el modelo, procederemos a hacer la prueba, es decir, predecir la clase de `X_test`y calcular las medidas de rendimiento

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Predecid la clase de `X_test`, calculad la exacitud de la predicción.
# - Calculad la matriz de confusión
#
# </div>

# %%
# Exactitud con el test:
score = sqt.evaluate(X_test, y_test)
# Out:
# 1781/1781 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9993

# %%
# Predicción:
pred_test = sqt.predict(X_test)
# Out:
# 1781/1781 [==============================] - 3s 1ms/step

# %%
# Categorizamos vectores: 
pred_test = np.argmax(pred_test, axis=1)
y_test = np.argmax(y_test, axis=1)
np.unique(pred_test)
# Out:
# array([0, 1])

# %%
# Matriz de confusión:
print(confusion_matrix(y_test, pred_test))
# Out:
# [[56848    16]
#  [   23    75]]

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test, pred_test, average=None))
print(classification_report(y_test, pred_test))
# Out:
# [0.9996571  0.79365079]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.82      0.77      0.79        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.88      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Qué opinas de los resultados?, ¿nos podemos quedar con este modelo como aceptable?
#    - ¿Las medidas de rendimiento usadas son aceptables? ¿Que otra medida de rendimiento propondrías?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# Considero que no son resultados buenos ya que el error tipo I es alto, es decir, se falla mucho a la hora de predecir si hay fraude o no.
#
# La matriz de confusión nos aporta toda la informacion que necesitamos para saber el rendimiento del modelo. Monitorizar el error tipo I es la mejor medida de rendimiento para saber si existe fraude o no.
#
#
# </div>

# %% [markdown]
# ## 2.3. Submuestreo
#
# El submuestreo se refiere a la técnica de reducir el número de muestras de la clase mayoritaria para equilibrar la distribución de clases en un conjunto de datos.  Esto se puede lograr eliminando aleatoriamente muestras de la clase mayoritaria.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Reduce el número de observaciones de la clase mayoritaria del conjunto de datos `X_train` hasta que tenga el mismo número de observaciones que la clase minoritaria. Muestra las dimensiones de las nuevas matrices de entrenamiento i la frecuencia de cada clase. Podéis utilizar la fución `resample` dela bibioteca `utils` de `sklearn`
# - Cread, entrenad, graficad las pérdidas y exactitud durante el entreno, validad y probad otro modelo `Sequential` con la misma configuración del apartado anterior.
# </div>

# %%
from sklearn.utils import resample

# Reconvertimos los vectores a las etiquetas de clase "0" y "1":
class_data = np.argmax(y_train, axis=1)

# Creamos un nuevo dataset:
train_data = X_train

# Incluimos la clase o variables objetivo:
train_data['Class'] = class_data

# %%
# Observamos el nº de casos en los que hay fraude, que es la clase minoritaria:
n_fraude = train_data['Class'].value_counts()[1]
n_fraude
# Out:
# 394

# %%
# Separamos la clase mayoritaria:
nfraude = train_data[train_data['Class'] == 0]

# Separamos la clase minoritaria:
fraude = train_data[train_data['Class'] == 1]

# %%
# Reducimos los casos de no fraude según el número de fraudes del dataset:
train_data_downsampled = resample(nfraude, n_samples=n_fraude, replace=True)

# %%
# Chequeamos:
train_data_downsampled['Class'].value_counts()
# Out:
# 0    394
# Name: Class, dtype: int64

# %%
# Apilamos el conjunto con el de fraudes que habíamos separado:
train_data_downsampled = pd.concat([train_data_downsampled, fraude])

train_data_downsampled.head()
# Out:
#                0         1         2         3         4         5         6  \
# 47389  -1.033859  0.224858  0.373737 -0.432052  4.196815 -3.435438 -3.011424
# 201042 -0.643138  0.538400  1.011295 -0.865934  0.059952  0.651527 -0.114159
# 90755   0.522573 -0.220375  0.790165  1.148646 -0.591153  0.661590 -0.607017
# 155372  0.044577  0.618518 -0.209651 -0.444810  0.677728 -0.427024  0.740190
# 97063   0.709768 -0.259274  0.285122 -0.405795 -0.781393 -0.774048 -0.341464
#
#                7         8         9  ...        20        21         22  \
# 47389  -0.751274  0.245665 -1.334862  ...  1.179865 -1.468377 -12.482376
# 201042  0.840527  0.216627 -1.208533  ... -0.107811 -0.282026  -0.171885
# 90755   0.448201  1.161105 -0.178500  ... -0.522204 -1.054566   0.140355
# 155372 -0.002193 -0.362667 -0.627151  ... -0.372734 -0.904053   0.160032
# 97063  -0.210185 -0.806744  0.608552  ... -0.613178 -1.099973   0.172129
#
#               23        24        25        26        27        28  Class
# 47389   0.211159 -0.971222 -0.646692  1.143882  0.944758 -1.455077      0
# 201042 -1.806807  0.192486 -0.052073  0.488076  0.154451 -0.896032      0
# 90755  -0.042677  0.632433 -1.081315  0.182339  0.048190 -0.085047      0
# 155372  1.114125 -0.860672  0.175578  0.546301  0.237393 -0.482246      0
# 97063   0.698459  0.296139  1.965086 -0.133448  0.034090 -0.430507      0
#
# [5 rows x 30 columns]

# %%
# Comprobamos distribución de clases:
train_data_downsampled['Class'].value_counts()
# Out:
# 0    394
# 1    394
# Name: Class, dtype: int64

# %%
# Dividimos la variable objetivo y los descriptores:
y_train = train_data_downsampled.pop('Class')

X_train = train_data_downsampled

# %%
# Transformamos la variable objetivo en vectores binarios:
y_train = to_categorical(y_train, num_classes=2, dtype='int32')
y_test = to_categorical(y_test, num_classes=2, dtype='int32')

# %%
# Modelo:
sqt_2 = Sequential()

# Agregamos 4 capas ocultas e indicamos el orden de las entradas:
sqt_2.add(keras.layers.Dense(20, activation='relu', input_shape=[X_train.shape[1]]))
sqt_2.add(keras.layers.Dense(20, activation='relu'))
sqt_2.add(keras.layers.Dense(20, activation='relu'))
sqt_2.add(keras.layers.Dense(20, activation='relu'))

# Le indicamos 2 neuronas:
sqt_2.add(keras.layers.Dense(2, activation='sigmoid'))
sqt_2.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')

# Resumen:
sqt_2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 20)                600
#
#  dense_41 (Dense)            (None, 20)                420
#
#  dense_42 (Dense)            (None, 20)                420
#
#  dense_43 (Dense)            (None, 20)                420
#
#  dense_44 (Dense)            (None, 2)                 42
#
# =================================================================
# Total params: 1,902
# Trainable params: 1,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamos el modelo:
f_model = sqt_2.fit(X_train, y_train, epochs=100, batch_size=2048, validation_split=0.2, verbose=0)

# %%
# Encapsulamos la historia (los valores para cada época que ha ido generando):
hist = pd.DataFrame(f_model.history)
# Añadimos el número de la época, que necesitaremos para graficar:
hist['epoch'] = f_model.epoch
hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy  epoch
# 0  0.721273  0.426984  0.597146      0.955696      0
# 1  0.692607  0.439683  0.534461      0.955696      1
# 2  0.668415  0.449206  0.482779      0.962025      2
# 3  0.648821  0.450794  0.439989      0.974684      3
# 4  0.633101  0.461905  0.406216      0.974684      4

# %%
plt.figure(figsize=(10,10))

# Graficamos por un lado el error de entrenamiento y de validación:
plt.xlabel('epoch')
plt.ylabel('Loss vs Iterations')
plt.plot(hist['epoch'], hist['loss'], label = 'Error de entrenamiento')
plt.plot(hist['epoch'], hist['val_loss'], label = 'Error de validación')
plt.legend()

# %%
plt.figure(figsize=(10,10))

# Graficamos la precisión de entrenamiento y la de validación:
plt.xlabel('epoch')
plt.ylabel('Accuracy vs Iterations')
plt.plot(hist['epoch'], hist['accuracy'], label = 'Precisión entrenamiento')
plt.plot(hist['epoch'], hist['val_accuracy'], label = 'Precisión validación')
plt.legend()

# %%
# Exactitud:
score = sqt_2.evaluate(X_test, y_test)
# Out:
# 1781/1781 [==============================] - 4s 2ms/step - loss: 0.1126 - accuracy: 0.9690

# %%
# Predecimos la clase de "X_test":
pred_test = sqt_2.predict(X_test)
# Out:
# 1781/1781 [==============================] - 2s 1ms/step

# %%
# Pasamos los vectores binarios a categorías: 
pred_test = np.argmax(pred_test, axis=1)
y_test = np.argmax(y_test, axis=1)
np.unique(pred_test)
# Out:
# array([0, 1])

# %%
print(confusion_matrix(y_test, pred_test))
# Out:
# [[55106  1758]
#  [    9    89]]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
# - ¿Porqué crees que se ha hecho un remuestreo solo a los datos de entrenamiento?
# - ¿Qué opinas de los resultados?, ¿nos podemos quedar con este modelo como aceptable?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# El remuestreo solo a los datos de entrenamiento se hace para evitar el sobreajuste del modelo. El sobreajuste ocurre cuando el modelo se ajusta demasiado bien a los datos de entrenamiento y no generaliza bien a los datos nuevos.
# El error que se comete en la validacion es un poco mas alto que en el muestreo, por lo que parece que tenemos un buen modelo, con exactitud cerca de 0.95 sin embargo el error tipo I es demasiado alto, por lo que creo que no tenemos un buen modelo.
# </div>

# %% [markdown]
# ## 2.4. Sobremuestreo
#
# Al contrario que el caso anterior, el sobremuestreo se refiere a la técnica de aumentar el número de muestras de la clase minoritaria para equilibrar la distribución de clases en un conjunto de datos. Esto se puede lograr mediante la replicación de muestras existentes o mediante la generación de muestras sintéticas de las clases minoritarias

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Aumenta el número de observaciones de la clase minoritaria del conjunto de datos `X_train` hasta que tenga el mismo número de observaciones que la clase mayoritaria. Muestra las dimensiones de las nuevas matrices de entrenamiento i la frecuencia de cada clase.
# - Cread, entrenad, , graficad las pérdidas y exactitud durante el entreno, validad y probad otro modelo `Sequential` con la misma configuración del apartado anterior.
# </div>

# %%
# Número de casos NO hay fraude de la clase mayoritaria:
n_nfrauds = train_data['Class'].value_counts()[0]
n_nfrauds
# Out:
# 227451

# %%
# Creamos la clase mayoritaria:
nfraud = train_data[train_data['Class'] == 0]

# Creamos la clase minoritaria:
fraud = train_data[train_data['Class'] == 1]

# %%
# Reducimos los casos no fraude según el número de fraudes del dataset:
train_data_downsampled = resample(fraud, n_samples=n_nfrauds, replace=True)
train_data_downsampled['Class'].value_counts()
# Out:
# 1    227451
# Name: Class, dtype: int64

# %%
train_data_downsampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227451 entries, 215992 to 101469
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       227451 non-null  float64
#  1   1       227451 non-null  float64
#  2   2       227451 non-null  float64
#  3   3       227451 non-null  float64
#  4   4       227451 non-null  float64
#  5   5       227451 non-null  float64
#  6   6       227451 non-null  float64
#  7   7       227451 non-null  float64
#  8   8       227451 non-null  float64
#  9   9       227451 non-null  float64
#  10  10      227451 non-null  float64
#  11  11      227451 non-null  float64
#  12  12      227451 non-null  float64
#  13  13      227451 non-null  float64
#  14  14      227451 non-null  float64
#  15  15      227451 non-null  float64
#  16  16      227451 non-null  float64
#  17  17      227451 non-null  float64
#  18  18      227451 non-null  float64
#  19  19      227451 non-null  float64
#  20  20      227451 non-null  float64
#  21  21      227451 non-null  float64
#  22  22      227451 non-null  float64
#  23  23      227451 non-null  float64
#  24  24      227451 non-null  float64
#  25  25      227451 non-null  float64
#  26  26      227451 non-null  float64
#  27  27      227451 non-null  float64
#  28  28      227451 non-null  float64
#  29  Class   227451 non-null  int64
# dtypes: float64(29), int64(1)
# memory usage: 53.8 MB

# %%
# Apilamos los conjuntos:
train_data_downsampled = pd.concat([train_data_downsampled, nfraud])
train_data_downsampled.head()
# Out:
#                0         1          2         3         4         5  \
# 215992 -0.262116  2.931055  -5.238655  5.176175  0.265645 -1.539597
# 115841 -8.353326  5.600514 -15.292767  8.359929 -6.819881 -1.835673
# 28723  -7.640133  5.101264 -11.083987  5.824312 -9.777495 -2.084324
# 151913 -0.511280  2.032330  -3.635271  4.824496 -0.215510  0.071482
# 59348  -7.387067  3.948730 -11.639642  7.954489 -2.990932 -2.525958
#
#                 6         7         8          9  ...        20        21  \
# 215992  -2.350971  1.191673 -4.137436  -4.817660  ...  0.732382 -0.633778
# 115841 -13.549970  1.152730 -5.723984 -11.913862  ... -3.202367  1.385658
# 28723  -11.419398  8.025462 -7.010838 -13.035373  ...  3.709346 -0.139793
# 151913  -1.954354  1.071258 -2.518783  -4.084558  ...  0.601378 -0.957367
# 59348  -13.238283 -1.200662 -6.204166 -12.525784  ... -3.383148  0.472267
#
#               22        23        24        25        26        27        28  \
# 215992 -0.016270 -1.883126 -0.012864  1.094806  1.385613  0.390010 -1.584151
# 115841  1.877403 -1.729140 -0.068659  1.378798  5.267922 -4.359117 -1.455077
# 28723  -0.696688  0.857925  1.511468  0.133270 -4.026748 -3.399229  1.317841
# 151913  0.472376 -1.085827  0.194192  0.892564  2.045454  1.006818  1.128451
# 59348  -5.637861 -1.350924  0.293340  1.565832  6.717092 -3.054865 -1.455077
#
#         Class
# 215992      1
# 115841      1
# 28723       1
# 151913      1
# 59348       1
#
# [5 rows x 30 columns]

# %%
# Comprobamos la distribución de las clases:
train_data_downsampled['Class'].value_counts()
# Out:
# 1    227451
# 0    227451
# Name: Class, dtype: int64

# %%
# Dividimos la variable objetivo y los descriptores:
y_train = train_data_downsampled.pop('Class')

X_train = train_data_downsampled

# %%
print(y_train.shape, X_train.shape)
# Out:
# (454902,) (454902, 29)

# %%
# Transformamos la variable objetivo en vectores binarios:
y_train = to_categorical(y_train, num_classes=2, dtype='int32')
y_test = to_categorical(y_test, num_classes=2, dtype='int32')

# %%
#Modelo
sqt_3 = Sequential()

# Agregamos 4 capas ocultas e indicamos el orden de las entradas:
sqt_3.add(keras.layers.Dense(20, activation='relu', input_shape=[X_train.shape[1]]))
sqt_3.add(keras.layers.Dense(20, activation='relu'))
sqt_3.add(keras.layers.Dense(20, activation='relu'))
sqt_3.add(keras.layers.Dense(20, activation='relu'))

# Indicamos 2 neuronas y usaremos la función sigmoide por ser salida categórica:
sqt_3.add(keras.layers.Dense(2, activation='sigmoid'))

# Compilamos el modelo:
sqt_3.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
sqt_3.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 20)                600
#
#  dense_46 (Dense)            (None, 20)                420
#
#  dense_47 (Dense)            (None, 20)                420
#
#  dense_48 (Dense)            (None, 20)                420
#
#  dense_49 (Dense)            (None, 2)                 42
#
# =================================================================
# Total params: 1,902
# Trainable params: 1,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamos el modelo 
f_model = sqt_3.fit(X_train, y_train, epochs=100, batch_size=2048, validation_split=0.2, verbose=0)

# %%
# Encapsulamos la historia:
hist = pd.DataFrame(f_model.history)

# Añadimos el número de la época:
hist['epoch'] = f_model.epoch
hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy  epoch
# 0  0.375527  0.825262  0.140909      0.960673      0
# 1  0.084320  0.967317  0.074665      0.968895      1
# 2  0.039397  0.990336  0.042918      0.983183      2
# 3  0.020381  0.995796  0.026008      0.991438      3
# 4  0.012429  0.997689  0.017002      0.995208      4

# %%
plt.figure(figsize=(10,10))

# Graficamos el error de entrenamiento y del conjunto de validación:
plt.xlabel('epoch')
plt.ylabel('Loss vs Iterations')
plt.plot(hist['epoch'], hist['loss'], label = 'Error entrenamiento')
plt.plot(hist['epoch'], hist['val_loss'], label = 'Error validación')
plt.legend()

# %%
# Creamos una figura:
plt.figure(figsize=(10,10))

# Graficamos la precisión de entrenamiento y la precisión validación:
plt.xlabel('epoch')
plt.ylabel('Accuracy vs Iterations')
plt.plot(hist['epoch'], hist['accuracy'], label = 'Precisión entrenamiento')
plt.plot(hist['epoch'], hist['val_accuracy'], label = 'Precisión validación')
plt.legend()

# %%
# Exactitud:
score = sqt_3.evaluate(X_test, y_test)
# Out:
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0542 - accuracy: 0.9991

# %%
# Predicción de "X_test":
pred_test = sqt_3.predict(X_test)
# Out:
# 1781/1781 [==============================] - 2s 1ms/step

# %%
# Pasamos los vectores binarios a categorías: 
pred_test = np.argmax(pred_test, axis=1)
y_test = np.argmax(y_test, axis=1)
np.unique(pred_test)
# Out:
# array([0, 1])

# %%
print(confusion_matrix(y_test, pred_test))

from sklearn.metrics import f1_score
print(f1_score(y_test, pred_test, average=None))

print(classification_report(y_test, pred_test))
# Out:
# [[56839    25]
#  [   25    73]]
# [0.99956035 0.74489796]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.74      0.74      0.74        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.87      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Porqué crees que se ha hecho un remuestreo solo a los datos de entrenamiento?
#    - ¿Qué opinas de los resultados?, ¿nos podemos quedar con este modelo como aceptable?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
# El remuestreo solo a los datos de entrenamiento se hace para evitar el sobreajuste del modelo.
# Tenemos buenos valores de exactitud pero muchos falsos negativos. No creo que sea un buen modelo para predecir le fraude.
#
#
# </div>

# %% [markdown]
# ## 2.5. Generación de datos sintéticos
#
# SMOTE (Synthetic Minority Over-sampling Technique) es una técnica de sobremuestreo utilizada en el aprendizaje automático para abordar el problema de clases desequilibradas. SMOTE se utiliza para aumentar el número de muestras de la clase minoritaria al generar nuevas muestras sintéticas.
#
# La técnica SMOTE funciona de la siguiente manera: Para cada muestra en la clase minoritaria, SMOTE selecciona k vecinos cercanos y crea nuevas muestras en el espacio entre la muestra y sus vecinos. Estas nuevas muestras sintéticas son agregadas al conjunto de datos para aumentar el número de muestras de la clase minoritaria.
#
# La técnica SMOTE se utiliza en combinación con otras técnicas de preprocesamiento, como el submuestreo y la validación cruzada estratificada, para abordar el problema de clases desequilibradas en problemas de clasificación. Esta técnica puede mejorar la capacidad del modelo para aprender patrones de las clases minoritarias y puede aumentar el rendimiento en la clasificación de clases minoritarias.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Mediante la técnica SMOTE, aumenta el número de observaciones de la clase minoritaria de todo el conjunto de datos `X`. Puedes utilizar la función`SMOTE` de la librería `over_sampling` de la bibioteca `imblearn` .  Muestra las dimensiones de las nuevas matrices de entrenamiento y la frecuencia de cada clase.
# - Cread, entrenad, graficad las pérdidas y exactitud durante el entreno, validad y probad otro modelo `Sequential` con la misma configuración del apartado anterior.
# </div>

# %%
from imblearn.over_sampling import SMOTE

# %%
train_data.shape
# Out:
# (227845, 30)

# %%
# Dejamos la variable "y" en el estado original
y = np.argmax(y, axis=1)

# %%
smote = SMOTE(random_state=24)
# Aplicamos:
X_smote, y_smote = smote.fit_resample(X, y)

# %%
# Aplicamos:
X_smote, y_smote = smote.fit_resample(X, y)

# %%
# Vemos se han equilibrado las clases:
np.unique(y_smote, return_counts=True)
# Out:
# (array([0, 1]), array([284315, 284315]))

# %%
# Dividimos en conjuntos de netrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.2,
                                                                shuffle=True, random_state = 24, stratify=y_smote)

# %%
# comprobación de equilibrio de la distribución
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([227452, 227452]))

# %%
# Transformamos la variable objetivo en vectores binarios:
y_train = to_categorical(y_train, num_classes=2, dtype='int32')
y_test = to_categorical(y_test, num_classes=2, dtype='int32')

# %%
# Modelo
sqt_4 = Sequential()
# Capas ocultas
sqt_4.add(keras.layers.Dense(20, activation='relu', input_shape=[X_train.shape[1]]))
sqt_4.add(keras.layers.Dense(20, activation='relu'))
sqt_4.add(keras.layers.Dense(20, activation='relu'))
sqt_4.add(keras.layers.Dense(20, activation='relu'))

# %%
# Dos neuronas por querer predecir dos clases
sqt_4.add(keras.layers.Dense(2, activation='sigmoid'))
# Compilamos
sqt_4.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
sqt_4.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 20)                600
#
#  dense_51 (Dense)            (None, 20)                420
#
#  dense_52 (Dense)            (None, 20)                420
#
#  dense_53 (Dense)            (None, 20)                420
#
#  dense_54 (Dense)            (None, 2)                 42
#
# =================================================================
# Total params: 1,902
# Trainable params: 1,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamos el modelo
f_model = sqt_4.fit(X_train, y_train, epochs=100, batch_size=2048, validation_split=0.2, verbose=0)

# %%
# Encapsulamos la historia:
hist = pd.DataFrame(f_model.history)

# Añadimos el número de la época:
hist['epoch'] = f_model.epoch
hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy  epoch
# 0  0.254199  0.890408  0.081687      0.967268      0
# 1  0.053743  0.981021  0.037953      0.987580      1
# 2  0.028998  0.990907  0.025112      0.992559      2
# 3  0.020151  0.994180  0.019134      0.995032      3
# 4  0.014973  0.996093  0.015327      0.996230      4

# %%
plt.figure(figsize=(10,10))

# Graficamos el error de entrenamiento y error del conjunto de validación:
plt.xlabel('epoch')
plt.ylabel('Loss vs Iterations')
plt.plot(hist['epoch'], hist['loss'], label = 'Error de entrenamiento')
plt.plot(hist['epoch'], hist['val_loss'], label = 'Error validación')
plt.legend()

# %%
plt.figure(figsize=(10,10))

# Graficamos la precisión de entrenamiento y la precisión de validación:
plt.xlabel('epoch')
plt.ylabel('Accuracy vs Iterations')
plt.plot(hist['epoch'], hist['accuracy'], label = 'Precisión entrenamiento')
plt.plot(hist['epoch'], hist['val_accuracy'], label = 'Precisión validación')
plt.legend()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Análisis:</strong>
#
#    - ¿Porqué crees que en este caso si se puede hacer el remuestreo a todo el conjunto de datos?
#    - ¿Qué opinas de los resultados?, ¿Este es mejor que el anterior modelo? ¿nos podemos quedar con este modelo como aceptable?
#    - Enfocándonos en las variables descriptoras, ¿cómo crees que se puede mejorar la predicción?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Respuesta:</strong>
#
#
#
#
# </div>

# %% [markdown]
# ## 2.6. Sintonizando los modelos (BONUS)
#
# Los modelos anteriores se han configurado con hiperparámetros elegidos arbitrariamente y puede que no genere el modelo con el mejor rendimiento.  La búsqueda de hiperparámetros óptimos es importante porque permite encontrar la combinación de parámetros que maximiza el rendimiento del modelo en los datos de prueba o validación, lo que a su vez proporciona un modelo más generalizable y preciso para nuevos datos.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Implementación:</strong>
#
# - Mediante la función `GridSearchCV` de `sklearn.model_selection` y la función `KerasClassifier` de `keras.wrappers.scikit_learn`, encuentra los hiperparámetros óptimos para los modelos con los conjunto de datos: submuestreado, sobremuestreado y con generación sintética por medio de SMOTE.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>Solución:</strong>
# </div>
